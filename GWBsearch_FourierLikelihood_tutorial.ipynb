# %% [markdown]
# # Tutorial for a GWB search on a PTA dataset with the Fourier likelihood
#
# paper reference: *add link* [Fig. 2]
#
# In this notebook, we present a tutorial about how to use the likelihood in Fourier domain (presented in our paper) for a GWB search on a (radio) PTA dataset. In particular, we will use the public data from EPTA DR2new (https://zenodo.org/records/8164425).
#
# One of the main advantages of this formulation is that it allows to divide the GWB search in a two-step analysis:
# - step 1: each pulsar is analyzed individually, and we focus on the signals that are not covariant with a GWB (white noise, deterministic signals, etc.). The hyperparameters of the signals covariant with a GWB are fixed to some values (in this example: log_A = -12, gamma = 5, log_kappa = -5 for both RN and DM variations).
# - step 2: we look at the whole array simultaneously and carry inference for the GWB signals and for the signals covariant with it (red noise, DM variations, etc.). The signals investigated in the previous step are marginalized over.
#
# In this example, we use the 25 pulsars of EPTA DR2new. The noise model includes white noise (efac and equad specific for each observing backend), RN and DM variations (dm_gp) for each pulsar, modeled as a gaussian process over, respectively, 30 and 100 frequency bins, and with a spectrum fitted by a flat-tail powerlaw. Furthermore, pulsar J1600-3053 presents a chromatic red noise and J1713+0747 one exponential DM dip (see the function *pulsar_model* form more details).
#
#
# NB: for some enterprise extension functions this script uses a modified versions contained in the python file *sere_enterprise.py*.

# %%
from __future__ import division
import sys, os, json, pickle
import numpy as np
import scipy.linalg as sl
import la_forge.gp as lfgp
import _pickle as cPickle

import enterprise.signals.parameter as parameter
from enterprise.signals import utils
from enterprise.signals import signal_base
from enterprise.signals import selections
from enterprise.signals.selections import Selection
from enterprise.signals import white_signals
from enterprise.signals import gp_signals
import enterprise.constants as const
from enterprise_extensions import sampler

import corner
from PTMCMCSampler.PTMCMCSampler import PTSampler as ptmcmc

import sere_enterprise as sere
# Out:
# Optional acor package is not installed. Acor is optionally used to calculate the effective chain length for output in the chain file.
# Warning: cannot find astropy, units support will not be available.

# %%
####################################   FUNCTIONS    #################################### 

# build PTA object
#--------------------------------------------------------------------------------

def pulsar_model(psr, model_base, inc_chrom=True, inc_dmdip=True, fix_dip=True, fix_chrom=True):

    # chromatic noise
    if psr.name == 'J1600-3053' and inc_chrom == True:
        
        if fix_chrom == True:
            chrom = sere.chromatic_noise_block(components=93,gp_kernel='diag', psd='flat_powerlaw',gamma_val=5, logA_val=-12,logk_val=-5)
        else:
            chrom = sere.chromatic_noise_block(components=93,gp_kernel='diag', psd='flat_powerlaw')  
        model = model_base + chrom

    # DM dip
    elif psr.name == 'J1713+0747' and inc_dmdip == True:
        
        dm_expdip_tmin=[54650, 57490]
        dm_expdip_tmax=[54850, 57530]
        tmin = (dm_expdip_tmin if isinstance(dm_expdip_tmin, list)
                else [dm_expdip_tmin])
        tmax = (dm_expdip_tmax if isinstance(dm_expdip_tmax, list)
                else [dm_expdip_tmax])
        num_dmdips = 2
        dm_expdip_idx=[4,1]
        dm_expdip_idx = (dm_expdip_idx if isinstance(dm_expdip_idx,list)
                                        else [dm_expdip_idx]*int(num_dmdips))
        dm_expdip_sign='negative'
        dm_expdip_sign = (dm_expdip_sign if isinstance(dm_expdip_sign,list)
                                            else [dm_expdip_sign]*int(num_dmdips))

        if fix_dip == True:
            for dd in range(num_dmdips):
                dmdip = sere.dm_exponential_dip(tmin=tmin[dd], tmax=tmax[dd],
                                                        idx=dm_expdip_idx[dd],
                                                        sign=dm_expdip_sign[dd],
                                                        name='dmexp_{0}'.format(dd+1),
                                                        t0_dmexp_val=57510, log10_Amp_dmexp_val=-6, log10_tau_dmexp_val=1.5)
        else:
            for dd in range(num_dmdips):
                dmdip = sere.dm_exponential_dip(tmin=tmin[dd], tmax=tmax[dd],
                                                        idx=dm_expdip_idx[dd],
                                                        sign=dm_expdip_sign[dd],
                                                        name='dmexp_{0}'.format(dd+1))
        model = model_base + dmdip

    else:
        model = model_base

    return model(psr)


def build_pta (psrs, fix_rn=True, fix_dm=True, fix_wn=True, logA_red=-15, gamma_red=4, logA_dm=-16, gamma_dm=3, log_kappa=-6, inc_chrom=True, inc_dmdip=True, fix_dip=True, fix_chrom=True, inc_crn=True, hd=True):

    # find the maximum time span to set GW frequency sampling
    tmin = [p.toas.min() for p in psrs]
    tmax = [p.toas.max() for p in psrs]
    Tspan = np.max(tmax) - np.min(tmin)

    # timing model
    tm = gp_signals.MarginalizingTimingModel(use_svd=True)

    # white noise
    if fix_wn == True:
        efac = parameter.Constant()
        equad = parameter.Constant()
    else:
        efac = parameter.Uniform(0.1,5)
        equad = parameter.Uniform(-10,-5)
    ef = white_signals.MeasurementNoise(efac=efac, selection=Selection(selections.by_backend))
    eq = white_signals.TNEquadNoise(log10_tnequad=equad, selection=Selection(selections.by_backend))

    # red noise
    if fix_rn == True:
        rn_log10_A = parameter.Constant(logA_red)
        rn_gamma = parameter.Constant(gamma_red)
        rn_log10_kappa = parameter.Constant(log_kappa)
    else:
        rn_log10_A = parameter.Uniform(-18, -12)
        rn_log10_kappa = parameter.Uniform(-9,-4)
        rn_gamma = parameter.Uniform(0,7)
    rn_pl = sere.powerlaw_flat_tail(log10_A=rn_log10_A, gamma=rn_gamma, log10_kappa=rn_log10_kappa)
    rn = gp_signals.FourierBasisGP(spectrum=rn_pl, components=30, Tspan=Tspan)

    # DM variations
    if fix_dm == True:
        dm_log10_A = parameter.Constant(logA_dm)
        dm_gamma = parameter.Constant(gamma_dm) 
        dm_log10_kappa = parameter.Constant(log_kappa)
    else:
        dm_log10_A = parameter.Uniform(-18, -12)
        dm_gamma = parameter.Uniform(0,7)
        dm_log10_kappa = parameter.Uniform(-9,-4)
    pl_dm = sere.powerlaw_flat_tail(log10_A=dm_log10_A, gamma=dm_gamma, log10_kappa=dm_log10_kappa)
    dm_basis = utils.createfourierdesignmatrix_dm(nmodes=100)
    dm = gp_signals.BasisGP(priorFunction=pl_dm, basisFunction=dm_basis, name='dm')

    if hd == True:
        # HD correlated background
        crn = sere.common_red_noise_block(psd='powerlaw', prior='log-uniform', Tspan=Tspan, components=9,  logmin=-15.5, logmax=-13.5, gamma_val=None, name='gw',orf='hd')
    else:
        # common red noise signal (uncorrelated)
        crn = sere.common_red_noise_block(psd='powerlaw', prior='log-uniform', Tspan=Tspan, components=9,  logmin=-15.5, logmax=-13.5, gamma_val=None, name='crn')

    # base model
    model_base = tm + ef + eq + rn + dm

    if inc_crn == True:
        model_base += crn

    return signal_base.PTA([pulsar_model(psr,model_base,inc_chrom=inc_chrom, inc_dmdip=inc_dmdip, fix_dip=fix_dip, fix_chrom=fix_chrom) for psr in psrs])


# update covariance formula
#--------------------------------------------------------------------------------

def update_cov(Cs,ms,ns,npsrs):

    C_list = []
    n_mat = len(ns)

    for p in range(npsrs):
        C = 0
        m = 0
        for i in range(n_mat):
            C += (ns[i])*Cs[i][p][:][:] + ns[i]*ms[i][p][:].T*ms[i][p][:] 
            m += ns[i]*ms[i][p][:]

        m = m/np.sum(ns)
        C = C - np.sum(ns)*m.T*m
        C = C/(np.sum(ns))
        C_list.append(C)
        
    return C_list

# %%
##### FOURIER LIKELIHOOD
#--------------------------------------------------------------------------------

def log_likelihood_Fourier(xs):

    '''
        New Fourier likelihood for pta array
    '''
    params = xs if isinstance(xs, dict) else pta_fl.map_params(xs)

    phiinvs = pta_fl.get_phiinv(params, logdet=True) 

    loglike = 0
    loglike += -0.5 * np.sum([ell for ell in pta_fl.get_rNr_logdet(params)])
    loglike += sum(pta_fl.get_logsignalprior(params))

    if pta_fl._commonsignals:
        
        phiinv, logdet_phiinv = phiinvs
        
        Sigma_inv = Sigma_0_inv - phiinv_00 + phiinv
        Li, lower = sl.cho_factor(Sigma_inv, lower=True)
        
        Sigma = sl.cho_solve((Li,True), np.identity(len(Li)))
        expval = sl.cho_solve((Li,True), Si0_a_hat)
        logdet_sigma = np.sum(2 * np.log(np.diag(Li)))
        
        loglike += - 0.5 * logdet_phiinv
        loglike += 0.5 * (np.dot(Si0_a_hat, expval) - logdet_sigma)

    else:

        for Sigma_0_inv_p, pl_0, pl, Si0_a_hat_p in zip(Sigma_0_inv,phiinvs_0, phiinvs, Si0_a_hat):

            phiinv, logdet_phiinv = pl
            phiinv_0, logdet_phiinv_0 = pl_0
            
            Sigma_inv = Sigma_0_inv_p - np.diag(phiinv_0) + np.diag(phiinv)
            Li, lower = sl.cho_factor(Sigma_inv, lower=True)

            Sigma = sl.cho_solve((Li,True), np.identity(len(Li)))
            expval = sl.cho_solve((Li,True), Si0_a_hat_p)
            logdet_sigma = np.sum(2 * np.log(np.diag(Li)))

            loglike += - 0.5 * logdet_phiinv
            loglike += 0.5 * (np.dot(Si0_a_hat_p, expval) - logdet_sigma)
    
    return loglike

# %%
##########################  MAIN CODE ###########################################

# %%
home_dir = '...'
mcmc_dir = home_dir + '...'
os.system('mkdir '+mcmc_dir)

i_logA = -12
i_gamma = 5
i_logk = -5

# reading the psrs pickle
pkl_dir = home_dir + 'psrsDR2new.pkl'
with open(pkl_dir, 'rb') as f:
    psrs = pickle.load(f)
    f.close()

Npsrs = len(psrs)
print(len(psrs))

# reading the WN dictionary
wn_dict_dir = home_dir + 'DR2new_Wnoise.json'
with open(wn_dict_dir, 'r') as f:
    Wnoise_ml = json.load(f)
    f.close()
# Out:
# 25

# %% [markdown]
# ### Step 1:
#
# The first step has been carried out outside this notebook. Separately for each pulsar, we sampled over the white noise parameters (for J1713+0747 we sampled over the DM dip parameters as well), while the RN and DM variations hyperparameters were fixed (log_A = -12, gamma = 5, log_kappa = -5 for both RN and DM variations).
#
# The obtained chains of white noise parameter samples are used to evaluate the quantities $\hat{a}_0$ and $\Sigma_0$ that are needed to construct the Fourier likelihood.
#
# NB: when carrying out this first step, even if each pulsar is analyzed individually, the time span of the Fourier decomposition (Tspan parameter) must be defined as the Tspan of the whole array of pulsars.

# %% [markdown]
# ### Step 2:
#
# We sample over GWB, RN and DM hyperparameters with the Fourier likelihood:
#
# $$\begin{aligned}
#     {\rm ln} \Bigl( p(\rho, \theta |\{\delta t\}) \Bigr) & = \int {\rm d}^{N_p}a \, {\rm ln} \Bigl[p(\{ a\},\rho_0, \theta | \{\delta t\}) \times
#     \frac{p( \{a\}|\rho)p(\rho)}{p( \{a\}|\rho_0)p(\rho_0)} \Bigr] \\
#     &  = \frac{1}{2} \hat{a}_0^T \Sigma_0^{-1} \Sigma \Sigma_0^{-1}\hat{a}_0 - \frac{1}{2}
#     \delta t^T \tilde{N}^{-1} \delta t - \frac{1}{2} \bigl[
#     {\rm lndet}(2\pi N) + {\rm lndet}(2\pi M^TN^{-1}M) + {\rm lndet}(2\pi\phi) -
#      {\rm lndet}(2\pi \Sigma) \bigr] \, ,
#     \end{aligned}$$
#
# which is Eq. (19) of our paper.

# %%
# building the PTA objects
pta_0 = build_pta(psrs, fix_wn=False, fix_dip=False, inc_crn=False, inc_dmdip=True, inc_chrom=True)
pta_fl = build_pta(psrs, fix_rn=False, fix_dm=False, fix_chrom=False, inc_crn=True, fix_dip=True, inc_dmdip=True, inc_chrom=True)
pta_fl.set_default_params(Wnoise_ml)
# Out:
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.P200.1380_efac to 1.1045950948818555
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.P217.1380_efac to 0.848194739410362
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.PS110.2487_efac to 0.9443048546615437
# INFO: enterprise.signals.signal_base: Setting J0030+0451_JBO.ROACH.1520_efac to 0.9184905449812792
# INFO: enterprise.signals.signal_base: Setting J0030+0451_LEAP.1396_efac to 1.4194567362018933
# INFO: enterprise.signals.signal_base: Setting J0030+0451_NRT.NUPPI.1484_efac to 0.776131390132143
# INFO: enterprise.signals.signal_base: Setting J0030+0451_NRT.NUPPI.1854_efac to 1.1089143495690343
# INFO: enterprise.signals.signal_base: Setting J0030+0451_WSRT.P2.1380_efac to 0.3381260667250748
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.P200.1380_log10_tnequad to -6.168262261771374
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.P217.1380_log10_tnequad to -7.898145381752085
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.PS110.2487_log10_tnequad to -6.263274196060782
# INFO: enterprise.signals.signal_base: Setting J0030+0451_JBO.ROACH.1520_log10_tnequad to -6.873679824259591
# INFO: enterprise.signals.signal_base: Setting J0030+0451_LEAP.1396_log10_tnequad to -7.035431021176787
# INFO: enterprise.signals.signal_base: Setting J0030+0451_NRT.NUPPI.1484_log10_tnequad to -7.984517962133032
# INFO: enterprise.signals.signal_base: Setting J0030+0451_NRT.NUPPI.1854_log10_tnequad to -6.4987472770497625
# INFO: enterprise.signals.signal_base: Setting J0030+0451_WSRT.P2.1380_log10_tnequad to -5.25577145703114
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.P200.1380_efac to 1.2810562728735235
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.P217.1380_efac to 1.2597018806785478
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.S110.2487_efac to 1.2266737944057213
# INFO: enterprise.signals.signal_base: Setting J0613-0200_JBO.ROACH.1520_efac to 0.911716114279691
# INFO: enterprise.signals.signal_base: Setting J0613-0200_LEAP.1396_efac to 0.6820842370183298
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.1484_efac to 0.8277857078402245
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.1854_efac to 0.7089371243040629
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.2539_efac to 0.8444149024880875
# INFO: enterprise.signals.signal_base: Setting J0613-0200_WSRT.P2.1380_efac to 1.2794135321268916
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.P200.1380_log10_tnequad to -7.688200368312655
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.P217.1380_log10_tnequad to -6.956714232036004
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.S110.2487_log10_tnequad to -6.526872383435261
# INFO: enterprise.signals.signal_base: Setting J0613-0200_JBO.ROACH.1520_log10_tnequad to -7.207738643749434
# INFO: enterprise.signals.signal_base: Setting J0613-0200_LEAP.1396_log10_tnequad to -6.3944038538275905
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.1484_log10_tnequad to -8.60165405615579
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.1854_log10_tnequad to -8.634364542894792
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.2539_log10_tnequad to -8.131395892976768
# INFO: enterprise.signals.signal_base: Setting J0613-0200_WSRT.P2.1380_log10_tnequad to -7.7779273400896365
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.P200.1380_efac to 1.4622887414114853
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.P217.1380_efac to 1.1182322606329167
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.S110.2487_efac to 1.2021518407383947
# INFO: enterprise.signals.signal_base: Setting J0751+1807_JBO.ROACH.1520_efac to 0.9659487293118227
# INFO: enterprise.signals.signal_base: Setting J0751+1807_LEAP.1396_efac to 0.9858262574040735
# INFO: enterprise.signals.signal_base: Setting J0751+1807_NRT.NUPPI.1484_efac to 0.8765546208048559
# INFO: enterprise.signals.signal_base: Setting J0751+1807_NRT.NUPPI.2539_efac to 0.8712565953680692
# INFO: enterprise.signals.signal_base: Setting J0751+1807_WSRT.P2.1380_efac to 1.0578633335599714
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.P200.1380_log10_tnequad to -5.855316110896133
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.P217.1380_log10_tnequad to -5.951730622301865
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.S110.2487_log10_tnequad to -8.273874757633164
# INFO: enterprise.signals.signal_base: Setting J0751+1807_JBO.ROACH.1520_log10_tnequad to -8.892936209777913
# INFO: enterprise.signals.signal_base: Setting J0751+1807_LEAP.1396_log10_tnequad to -7.228475518428845
# INFO: enterprise.signals.signal_base: Setting J0751+1807_NRT.NUPPI.1484_log10_tnequad to -7.240212548545826
# INFO: enterprise.signals.signal_base: Setting J0751+1807_NRT.NUPPI.2539_log10_tnequad to -6.521626337818643
# INFO: enterprise.signals.signal_base: Setting J0751+1807_WSRT.P2.1380_log10_tnequad to -6.760179341150843
# INFO: enterprise.signals.signal_base: Setting J0900-3144_JBO.ROACH.1520_efac to 1.04101013120358
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.1484_efac to 0.8506499833973288
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.1854_efac to 1.4944510649111937
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.2154_efac to 1.1280088187462487
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.2539_efac to 0.9074278562818382
# INFO: enterprise.signals.signal_base: Setting J0900-3144_JBO.ROACH.1520_log10_tnequad to -6.1579476020947235
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.1484_log10_tnequad to -6.1208882351205895
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.1854_log10_tnequad to -8.771532099848624
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.2154_log10_tnequad to -6.6692139276891975
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.2539_log10_tnequad to -8.857058345244642
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.P200.1380_efac to 1.0548133535433428
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.P217.1380_efac to 1.0877812691698507
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.S110.2487_efac to 0.989805594951363
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.S60.4857_efac to 0.8301538451582426
# INFO: enterprise.signals.signal_base: Setting J1012+5307_JBO.ROACH.1520_efac to 0.9641677541515948
# INFO: enterprise.signals.signal_base: Setting J1012+5307_LEAP.1396_efac to 1.4332993699844783
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.1484_efac to 0.8472184300814208
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.1854_efac to 0.8143047394107772
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.2539_efac to 0.7671972870699303
# INFO: enterprise.signals.signal_base: Setting J1012+5307_WSRT.P2.1380_efac to 1.237984987345866
# INFO: enterprise.signals.signal_base: Setting J1012+5307_WSRT.P2.350_efac to 1.2892671667785593
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.P200.1380_log10_tnequad to -6.240183097594486
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.P217.1380_log10_tnequad to -6.804387306350895
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.S110.2487_log10_tnequad to -5.70344505119584
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.S60.4857_log10_tnequad to -8.674275925215627
# INFO: enterprise.signals.signal_base: Setting J1012+5307_JBO.ROACH.1520_log10_tnequad to -8.49205268487396
# INFO: enterprise.signals.signal_base: Setting J1012+5307_LEAP.1396_log10_tnequad to -6.681502406231853
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.1484_log10_tnequad to -8.859715211778916
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.1854_log10_tnequad to -6.240703159669776
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.2539_log10_tnequad to -7.236433417005013
# INFO: enterprise.signals.signal_base: Setting J1012+5307_WSRT.P2.1380_log10_tnequad to -7.693529095894691
# INFO: enterprise.signals.signal_base: Setting J1012+5307_WSRT.P2.350_log10_tnequad to -8.563979070953891
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.P200.1380_efac to 0.8102206481490057
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.P217.1380_efac to 0.7858128904591491
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.S110.2487_efac to 0.879606018512383
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.S60.4857_efac to 1.1737541790871822
# INFO: enterprise.signals.signal_base: Setting J1022+1001_JBO.ROACH.1520_efac to 1.0747453048700975
# INFO: enterprise.signals.signal_base: Setting J1022+1001_LEAP.1396_efac to 2.438256888182125
# INFO: enterprise.signals.signal_base: Setting J1022+1001_NRT.NUPPI.1484_efac to 0.805516529751389
# INFO: enterprise.signals.signal_base: Setting J1022+1001_WSRT.P2.1380_efac to 1.0806590482719904
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.P200.1380_log10_tnequad to -6.572227821559285
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.P217.1380_log10_tnequad to -7.005589378023857
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.S110.2487_log10_tnequad to -6.391685700921404
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.S60.4857_log10_tnequad to -5.6713037903220505
# INFO: enterprise.signals.signal_base: Setting J1022+1001_JBO.ROACH.1520_log10_tnequad to -5.826146883391521
# INFO: enterprise.signals.signal_base: Setting J1022+1001_LEAP.1396_log10_tnequad to -8.63537066059122
# INFO: enterprise.signals.signal_base: Setting J1022+1001_NRT.NUPPI.1484_log10_tnequad to -6.208441744577778
# INFO: enterprise.signals.signal_base: Setting J1022+1001_WSRT.P2.1380_log10_tnequad to -5.748242625477178
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.P200.1380_efac to 0.9551974352791707
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.P217.1380_efac to 0.9258318800843921
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.S110.2487_efac to 0.8396735963799056
# INFO: enterprise.signals.signal_base: Setting J1024-0719_JBO.ROACH.1520_efac to 0.9434863523119911
# INFO: enterprise.signals.signal_base: Setting J1024-0719_LEAP.1396_efac to 1.1523801155580489
# INFO: enterprise.signals.signal_base: Setting J1024-0719_NRT.NUPPI.1484_efac to 0.7687856834625707
# INFO: enterprise.signals.signal_base: Setting J1024-0719_NRT.NUPPI.2539_efac to 0.8045230724764365
# INFO: enterprise.signals.signal_base: Setting J1024-0719_WSRT.P2.1380_efac to 0.4653006137768964
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.P200.1380_log10_tnequad to -7.05065179837003
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.P217.1380_log10_tnequad to -6.189856602824119
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.S110.2487_log10_tnequad to -5.346016302576432
# INFO: enterprise.signals.signal_base: Setting J1024-0719_JBO.ROACH.1520_log10_tnequad to -8.21586325008337
# INFO: enterprise.signals.signal_base: Setting J1024-0719_LEAP.1396_log10_tnequad to -6.290103368658607
# INFO: enterprise.signals.signal_base: Setting J1024-0719_NRT.NUPPI.1484_log10_tnequad to -7.32549311640761
# INFO: enterprise.signals.signal_base: Setting J1024-0719_NRT.NUPPI.2539_log10_tnequad to -8.106099547840559
# INFO: enterprise.signals.signal_base: Setting J1024-0719_WSRT.P2.1380_log10_tnequad to -5.694096730161006
# INFO: enterprise.signals.signal_base: Setting J1455-3330_JBO.ROACH.1520_efac to 0.8043700135371057
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.1484_efac to 0.8407432349339051
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.1854_efac to 0.8338079763067537
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.2539_efac to 0.8883363918996182
# INFO: enterprise.signals.signal_base: Setting J1455-3330_JBO.ROACH.1520_log10_tnequad to -8.694817396061016
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.1484_log10_tnequad to -8.47992369819152
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.1854_log10_tnequad to -5.868863195311095
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.2539_log10_tnequad to -6.287320180876826
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.P200.1380_efac to 0.9165710995742749
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.P217.1380_efac to 1.7551021055815608
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.S110.2487_efac to 1.1549168980036049
# INFO: enterprise.signals.signal_base: Setting J1600-3053_JBO.ROACH.1520_efac to 1.217854326425572
# INFO: enterprise.signals.signal_base: Setting J1600-3053_LEAP.1396_efac to 1.9527327109252122
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.1484_efac to 0.7353004001394867
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.1854_efac to 0.9123422835055031
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.2154_efac to 0.749663602721091
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.2539_efac to 0.8038809724822832
# INFO: enterprise.signals.signal_base: Setting J1600-3053_WSRT.P2.1380_efac to 0.9704307198506573
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.P200.1380_log10_tnequad to -8.78681028514216
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.P217.1380_log10_tnequad to -5.519052538898048
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.S110.2487_log10_tnequad to -7.59331811415248
# INFO: enterprise.signals.signal_base: Setting J1600-3053_JBO.ROACH.1520_log10_tnequad to -6.8630253018403256
# INFO: enterprise.signals.signal_base: Setting J1600-3053_LEAP.1396_log10_tnequad to -8.096990503062509
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.1484_log10_tnequad to -6.9799998357772095
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.1854_log10_tnequad to -8.120215061110759
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.2154_log10_tnequad to -8.795040948819464
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.2539_log10_tnequad to -7.793228746717177
# INFO: enterprise.signals.signal_base: Setting J1600-3053_WSRT.P2.1380_log10_tnequad to -6.63125782756769
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.P200.1380_efac to 1.6740103438387088
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.P217.1380_efac to 1.0356321999126166
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.S110.2487_efac to 1.344823590532148
# INFO: enterprise.signals.signal_base: Setting J1640+2224_JBO.ROACH.1520_efac to 1.0900889895596009
# INFO: enterprise.signals.signal_base: Setting J1640+2224_LEAP.1396_efac to 1.0755152580227818
# INFO: enterprise.signals.signal_base: Setting J1640+2224_NRT.NUPPI.1484_efac to 0.9349544896349673
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.P200.1380_log10_tnequad to -8.119469937696858
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.P217.1380_log10_tnequad to -8.361131309787513
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.S110.2487_log10_tnequad to -8.33652279211746
# INFO: enterprise.signals.signal_base: Setting J1640+2224_JBO.ROACH.1520_log10_tnequad to -6.89888899120869
# INFO: enterprise.signals.signal_base: Setting J1640+2224_LEAP.1396_log10_tnequad to -7.3394633596342995
# INFO: enterprise.signals.signal_base: Setting J1640+2224_NRT.NUPPI.1484_log10_tnequad to -7.946053186812969
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.P200.1380_efac to 1.412374726303919
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.P217.1380_efac to 1.1826730155965852
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.S110.2487_efac to 1.843610252576271
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.S60.4857_efac to 0.9566210128555996
# INFO: enterprise.signals.signal_base: Setting J1713+0747_JBO.MK2.1520_efac to 0.8778418556697566
# INFO: enterprise.signals.signal_base: Setting J1713+0747_JBO.ROACH.1520_efac to 0.8794972097058603
# INFO: enterprise.signals.signal_base: Setting J1713+0747_LEAP.1396_efac to 1.552862675531769
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.1484_efac to 0.7896503325063164
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.1854_efac to 0.7079678541925291
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.2539_efac to 0.7731047657187958
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.1380_efac to 1.0345911103112715
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.2273_efac to 0.8427914809395443
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.350_efac to 0.898914858648177
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.P200.1380_log10_tnequad to -6.649000741215544
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.P217.1380_log10_tnequad to -6.6593602574637805
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.S110.2487_log10_tnequad to -7.9772772266290275
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.S60.4857_log10_tnequad to -8.312222023615337
# INFO: enterprise.signals.signal_base: Setting J1713+0747_JBO.MK2.1520_log10_tnequad to -8.095181552632685
# INFO: enterprise.signals.signal_base: Setting J1713+0747_JBO.ROACH.1520_log10_tnequad to -6.615228034705099
# INFO: enterprise.signals.signal_base: Setting J1713+0747_LEAP.1396_log10_tnequad to -6.7185150489060375
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.1484_log10_tnequad to -7.124620438769816
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.1854_log10_tnequad to -8.520459384443132
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.2539_log10_tnequad to -6.868562726735876
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.1380_log10_tnequad to -6.9716719287703555
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.2273_log10_tnequad to -6.676656824013697
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.350_log10_tnequad to -8.972410387384546
# INFO: enterprise.signals.signal_base: Setting J1730-2304_JBO.ROACH.1520_efac to 1.0966895598937743
# INFO: enterprise.signals.signal_base: Setting J1730-2304_NRT.NUPPI.1484_efac to 0.8936515336010582
# INFO: enterprise.signals.signal_base: Setting J1730-2304_NRT.NUPPI.2539_efac to 0.82955546014866
# INFO: enterprise.signals.signal_base: Setting J1730-2304_JBO.ROACH.1520_log10_tnequad to -8.76732339089998
# INFO: enterprise.signals.signal_base: Setting J1730-2304_NRT.NUPPI.1484_log10_tnequad to -7.092912342511541
# INFO: enterprise.signals.signal_base: Setting J1730-2304_NRT.NUPPI.2539_log10_tnequad to -8.070483707308561
# INFO: enterprise.signals.signal_base: Setting J1738+0333_EFF.P200.1380_efac to 1.2329115324118975
# INFO: enterprise.signals.signal_base: Setting J1738+0333_EFF.P217.1380_efac to 0.8867280280191301
# INFO: enterprise.signals.signal_base: Setting J1738+0333_JBO.ROACH.1520_efac to 0.7472756385097318
# INFO: enterprise.signals.signal_base: Setting J1738+0333_NRT.NUPPI.1484_efac to 0.8613738492525165
# INFO: enterprise.signals.signal_base: Setting J1738+0333_WSRT.P2.1380_efac to 1.1112003518112685
# INFO: enterprise.signals.signal_base: Setting J1738+0333_EFF.P200.1380_log10_tnequad to -6.79109245509378
# INFO: enterprise.signals.signal_base: Setting J1738+0333_EFF.P217.1380_log10_tnequad to -7.93640722539657
# INFO: enterprise.signals.signal_base: Setting J1738+0333_JBO.ROACH.1520_log10_tnequad to -5.43250967829
# INFO: enterprise.signals.signal_base: Setting J1738+0333_NRT.NUPPI.1484_log10_tnequad to -7.826039383135421
# INFO: enterprise.signals.signal_base: Setting J1738+0333_WSRT.P2.1380_log10_tnequad to -8.662202710812908
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.P200.1380_efac to 1.5289889739981626
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.P217.1380_efac to 1.2771057723574064
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.S110.2487_efac to 1.244705701316738
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.S60.4857_efac to 1.0561167945451462
# INFO: enterprise.signals.signal_base: Setting J1744-1134_JBO.ROACH.1520_efac to 1.1363656211662838
# INFO: enterprise.signals.signal_base: Setting J1744-1134_LEAP.1396_efac to 1.3136587135168925
# INFO: enterprise.signals.signal_base: Setting J1744-1134_NRT.NUPPI.1484_efac to 0.8171455527990248
# INFO: enterprise.signals.signal_base: Setting J1744-1134_NRT.NUPPI.2539_efac to 0.6214279693404747
# INFO: enterprise.signals.signal_base: Setting J1744-1134_WSRT.P2.1380_efac to 1.2098338519224716
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.P200.1380_log10_tnequad to -8.076864368319155
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.P217.1380_log10_tnequad to -7.778377010704876
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.S110.2487_log10_tnequad to -6.53903945008975
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.S60.4857_log10_tnequad to -7.257195389387301
# INFO: enterprise.signals.signal_base: Setting J1744-1134_JBO.ROACH.1520_log10_tnequad to -6.3815473236602775
# INFO: enterprise.signals.signal_base: Setting J1744-1134_LEAP.1396_log10_tnequad to -6.478777690017408
# INFO: enterprise.signals.signal_base: Setting J1744-1134_NRT.NUPPI.1484_log10_tnequad to -6.727670528542976
# INFO: enterprise.signals.signal_base: Setting J1744-1134_NRT.NUPPI.2539_log10_tnequad to -6.520348996009733
# INFO: enterprise.signals.signal_base: Setting J1744-1134_WSRT.P2.1380_log10_tnequad to -6.695781710027594
# INFO: enterprise.signals.signal_base: Setting J1751-2857_JBO.ROACH.1520_efac to 0.7549920950094138
# INFO: enterprise.signals.signal_base: Setting J1751-2857_NRT.NUPPI.1484_efac to 0.7531123951282895
# INFO: enterprise.signals.signal_base: Setting J1751-2857_JBO.ROACH.1520_log10_tnequad to -8.984319052277996
# INFO: enterprise.signals.signal_base: Setting J1751-2857_NRT.NUPPI.1484_log10_tnequad to -8.842148621404872
# INFO: enterprise.signals.signal_base: Setting J1801-1417_JBO.ROACH.1520_efac to 0.9864350427630586
# INFO: enterprise.signals.signal_base: Setting J1801-1417_NRT.NUPPI.1484_efac to 0.7483157602884402
# INFO: enterprise.signals.signal_base: Setting J1801-1417_JBO.ROACH.1520_log10_tnequad to -6.261181331261443
# INFO: enterprise.signals.signal_base: Setting J1801-1417_NRT.NUPPI.1484_log10_tnequad to -6.117048727714347
# INFO: enterprise.signals.signal_base: Setting J1804-2717_JBO.ROACH.1520_efac to 1.0057404787686226
# INFO: enterprise.signals.signal_base: Setting J1804-2717_NRT.NUPPI.1484_efac to 0.8049270400445149
# INFO: enterprise.signals.signal_base: Setting J1804-2717_JBO.ROACH.1520_log10_tnequad to -8.517548525232066
# INFO: enterprise.signals.signal_base: Setting J1804-2717_NRT.NUPPI.1484_log10_tnequad to -7.738473879868597
# INFO: enterprise.signals.signal_base: Setting J1843-1113_EFF.P217.1380_efac to 1.1814583391980884
# INFO: enterprise.signals.signal_base: Setting J1843-1113_EFF.S110.2487_efac to 0.8510196074666396
# INFO: enterprise.signals.signal_base: Setting J1843-1113_JBO.ROACH.1520_efac to 0.5085959354688436
# INFO: enterprise.signals.signal_base: Setting J1843-1113_NRT.NUPPI.1484_efac to 0.7483857925666096
# INFO: enterprise.signals.signal_base: Setting J1843-1113_WSRT.P2.1380_efac to 1.0406588880071412
# INFO: enterprise.signals.signal_base: Setting J1843-1113_EFF.P217.1380_log10_tnequad to -7.348379374130354
# INFO: enterprise.signals.signal_base: Setting J1843-1113_EFF.S110.2487_log10_tnequad to -7.178804349666641
# INFO: enterprise.signals.signal_base: Setting J1843-1113_JBO.ROACH.1520_log10_tnequad to -5.297139966908785
# INFO: enterprise.signals.signal_base: Setting J1843-1113_NRT.NUPPI.1484_log10_tnequad to -8.20133231501511
# INFO: enterprise.signals.signal_base: Setting J1843-1113_WSRT.P2.1380_log10_tnequad to -6.567219495870018
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.P200.1380_efac to 0.8903961781606221
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.P217.1380_efac to 0.5727944719143326
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.S110.2487_efac to 0.8872282802497014
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.S60.4857_efac to 0.7349637319778864
# INFO: enterprise.signals.signal_base: Setting J1857+0943_JBO.ROACH.1520_efac to 1.2238336779590848
# INFO: enterprise.signals.signal_base: Setting J1857+0943_LEAP.1396_efac to 1.5409148049950512
# INFO: enterprise.signals.signal_base: Setting J1857+0943_NRT.NUPPI.1484_efac to 0.9416000131448992
# INFO: enterprise.signals.signal_base: Setting J1857+0943_NRT.NUPPI.2539_efac to 0.9509516872455311
# INFO: enterprise.signals.signal_base: Setting J1857+0943_WSRT.P2.1380_efac to 0.9497468011319526
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.P200.1380_log10_tnequad to -8.08507027056367
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.P217.1380_log10_tnequad to -5.651476519327127
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.S110.2487_log10_tnequad to -5.5312698143074845
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.S60.4857_log10_tnequad to -8.426628290626866
# INFO: enterprise.signals.signal_base: Setting J1857+0943_JBO.ROACH.1520_log10_tnequad to -6.135956765069297
# INFO: enterprise.signals.signal_base: Setting J1857+0943_LEAP.1396_log10_tnequad to -6.855223837221721
# INFO: enterprise.signals.signal_base: Setting J1857+0943_NRT.NUPPI.1484_log10_tnequad to -8.900236976699127
# INFO: enterprise.signals.signal_base: Setting J1857+0943_NRT.NUPPI.2539_log10_tnequad to -8.33485330361282
# INFO: enterprise.signals.signal_base: Setting J1857+0943_WSRT.P2.1380_log10_tnequad to -8.621053689913959
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.1484_efac to 0.8540704265946855
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.1854_efac to 0.7676705441810963
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.2154_efac to 1.03247195323751
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.2539_efac to 0.7010197803207379
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.1484_log10_tnequad to -7.415073878834863
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.1854_log10_tnequad to -7.120859176440731
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.2154_log10_tnequad to -7.230582195698377
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.2539_log10_tnequad to -6.971700069604973
# INFO: enterprise.signals.signal_base: Setting J1910+1256_JBO.ROACH.1520_efac to 1.0605708987634797
# INFO: enterprise.signals.signal_base: Setting J1910+1256_NRT.NUPPI.1484_efac to 0.8345119172671124
# INFO: enterprise.signals.signal_base: Setting J1910+1256_JBO.ROACH.1520_log10_tnequad to -8.60288324441584
# INFO: enterprise.signals.signal_base: Setting J1910+1256_NRT.NUPPI.1484_log10_tnequad to -6.560712227869687
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.P200.1380_efac to 0.8761134222727486
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.P217.1380_efac to 1.4282541670316486
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.S110.2487_efac to 1.6558234534679714
# INFO: enterprise.signals.signal_base: Setting J1911+1347_JBO.ROACH.1520_efac to 0.8120162030722926
# INFO: enterprise.signals.signal_base: Setting J1911+1347_NRT.NUPPI.1484_efac to 0.8145191417597308
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.P200.1380_log10_tnequad to -6.325898247530114
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.P217.1380_log10_tnequad to -8.972867072178717
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.S110.2487_log10_tnequad to -5.8910997224670405
# INFO: enterprise.signals.signal_base: Setting J1911+1347_JBO.ROACH.1520_log10_tnequad to -5.504056196974953
# INFO: enterprise.signals.signal_base: Setting J1911+1347_NRT.NUPPI.1484_log10_tnequad to -8.815757478736355
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.P200.1380_efac to 0.911571024305496
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.P217.1380_efac to 1.1332353140352633
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.S110.2487_efac to 0.5276154326065083
# INFO: enterprise.signals.signal_base: Setting J1918-0642_JBO.ROACH.1520_efac to 0.9655238565741925
# INFO: enterprise.signals.signal_base: Setting J1918-0642_LEAP.1396_efac to 0.6781781812273364
# INFO: enterprise.signals.signal_base: Setting J1918-0642_NRT.NUPPI.1484_efac to 0.831041493837829
# INFO: enterprise.signals.signal_base: Setting J1918-0642_WSRT.P2.1380_efac to 0.9493532309055206
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.P200.1380_log10_tnequad to -6.339692244024356
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.P217.1380_log10_tnequad to -7.9507971426473105
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.S110.2487_log10_tnequad to -5.583677452793728
# INFO: enterprise.signals.signal_base: Setting J1918-0642_JBO.ROACH.1520_log10_tnequad to -6.332914721246314
# INFO: enterprise.signals.signal_base: Setting J1918-0642_LEAP.1396_log10_tnequad to -5.796154707117647
# INFO: enterprise.signals.signal_base: Setting J1918-0642_NRT.NUPPI.1484_log10_tnequad to -6.636962947462052
# INFO: enterprise.signals.signal_base: Setting J1918-0642_WSRT.P2.1380_log10_tnequad to -7.45893781848895
# INFO: enterprise.signals.signal_base: Setting J2124-3358_JBO.ROACH.1520_efac to 1.3225391415374796
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.1484_efac to 0.8358609453728573
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.1854_efac to 0.808915114390453
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.2154_efac to 1.128419743531647
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.2539_efac to 0.6632723665048084
# INFO: enterprise.signals.signal_base: Setting J2124-3358_JBO.ROACH.1520_log10_tnequad to -8.02686408638112
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.1484_log10_tnequad to -8.868578577184497
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.1854_log10_tnequad to -5.254878544747536
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.2154_log10_tnequad to -7.4274298640233125
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.2539_log10_tnequad to -5.366358828495574
# INFO: enterprise.signals.signal_base: Setting J2322+2057_EFF.P217.1380_efac to 1.2087043553497132
# INFO: enterprise.signals.signal_base: Setting J2322+2057_JBO.ROACH.1520_efac to 0.9610659725859465
# INFO: enterprise.signals.signal_base: Setting J2322+2057_NRT.NUPPI.1484_efac to 0.8809550106099319
# INFO: enterprise.signals.signal_base: Setting J2322+2057_EFF.P217.1380_log10_tnequad to -6.508521806272974
# INFO: enterprise.signals.signal_base: Setting J2322+2057_JBO.ROACH.1520_log10_tnequad to -6.054868484868762
# INFO: enterprise.signals.signal_base: Setting J2322+2057_NRT.NUPPI.1484_log10_tnequad to -8.583883932763115

# %%
# reading the Wn chains (obtained from step 1) to compute \Sigma_0 and \hat{a}_0
total_WNchain = []
check = 0
for p in psrs:
    chain_dir = home_dir + '.../chain_1.txt'
    psr_chain = np.loadtxt(chain_dir)
    inv_burn = int(0.25 * psr_chain.shape[0]) 
    if check == 0:
        total_WNchain = psr_chain[-inv_burn:,:-4]
        check = 1
    else:
        total_WNchain = np.concatenate((total_WNchain,psr_chain[-inv_burn:,:-4]),axis=1)

print('WN chains read')
# Out:
# WN chains read

# %%
# phiinv_0
phiinvs_0 = pta_0.get_phiinv([],logdet=True)

# %%
# Sigma_0_inv and a_hat
N = 10000
ns = np.ones(N)
lfrec = lfgp.Signal_Reconstruction(psrs, pta_0, total_WNchain, burn=0)
lfrec.reconstruct_coeffs = sere.reconstruct_coeffs
Sigma_0_inv_list = []
a_hat_list = []

for i in range(N):

    Sigma_0_inv_list_step = []
    a_hat_list_step = []
    idx = np.random.choice(np.arange(len(total_WNchain)), size=1, replace=False)
    params = lfrec.sample_posterior(idx)
    TNTs = pta_0.get_TNT(params)
    TNrs = pta_0.get_TNr(params)
    
    for TNr, TNT, pl in zip(TNrs, TNTs, phiinvs_0):
        if TNr is None:
            continue

        phiinv, logdet_phi = pl
        Sigma_0_inv_step = TNT + (np.diag(phiinv) if phiinv.ndim == 1 else phiinv)
        Li, lower = sl.cho_factor(Sigma_0_inv_step, lower=True)
        a_hat_step = sl.cho_solve((Li, True), TNr)
        Sigma_0_inv_list_step.append(Sigma_0_inv_step)
        a_hat_list_step.append(a_hat_step)

    Sigma_0_inv_list.append(Sigma_0_inv_list_step)
    a_hat_list.append(a_hat_list_step)


Sigma_0_inv = update_cov(Sigma_0_inv_list,a_hat_list,ns,Npsrs)
a_hat = [] 
for p in range(Npsrs):
    temp = 0
    for i in range(N):
        temp += a_hat_list[i][p][:]
    a_hat.append(temp/N)

# %%
# Sigma_0 * a hat
Si0_a_hat = []
for p in range(Npsrs):
    Si0_a_hat.append(np.dot(Sigma_0_inv[p][:][:], a_hat[p][:]))

# %%
if pta_fl._commonsignals:

    # phiinv_0
    phiinv_0 = []
    for i in range(Npsrs):
        phiinv_0 = np.concatenate((phiinv_0, phiinvs_0[i][0]))
    phiinv_0 = np.diag(phiinv_0)
    phiinv_00 = phiinv_0

    # Sigma_0_inv
    Sigma_0_inv = sl.block_diag(*Sigma_0_inv)

    # Sigma_0 * a hat
    Si0_a_hat_all = Si0_a_hat 
    Si0_a_hat = []
    for i in range(Npsrs):
        Si0_a_hat  = np.concatenate((Si0_a_hat , Si0_a_hat_all[i]))

# %%
# pickle up a backup for the 0 quantitities
pkl_dir = mcmc_dir + '/Sigma_0_inv.pkl'
with open(pkl_dir, "wb") as output_file:
    cPickle.dump(Sigma_0_inv, output_file)

pkl_dir = mcmc_dir + '/a_hat.pkl'
with open(pkl_dir, "wb") as output_file2:
    cPickle.dump(a_hat, output_file2)

# sampling params
np.savetxt(mcmc_dir+'/params.txt', pta_fl.param_names, fmt='%s')

# %%
# sampling
xs = {par.name: par.sample() for par in pta_fl.params}
print('test ln_likelihood: ',log_likelihood_Fourier(xs),'\n')

ndim = len(xs)
cov = np.diag(np.ones(ndim) * 0.01**2)
groups = None
Num = 2e6

sampler = ptmcmc(ndim, log_likelihood_Fourier, pta_fl.get_lnprior, cov, groups=groups, outDir=mcmc_dir, resume=False, seed=1234)
# Out:
# test ln_likelihood:  528762.4881111982

# %%
# sampling!
sampler.sample(x0, Num, SCAMweight=30, AMweight=15, DEweight=50)

# %% [markdown]
# With the method described in this notebook, we obtained posteriors for the hyperparameters of RN and DM variations hyperparameters for each pulsar (+ chromatic noise for J1600-3053), and for the GWB hyperparameters. The white noise and deterministic signals parameters are marginalised over. Those posteriors are compared in our paper with the ones obtained with the 'standard' time-domain likelihood in the case of a sampling over RN + DM + chrom + DM_dip + gwb (white noise parameters were fixed to reduce the computational costs). As shown in Fig.2 of our paper, the resulting posteriors for the GWB parameters are perfectly consistent.
#
# The purpose of this notebook is to show in a simplified way how to run a GWB search with the Fourier likelihood over a (radio) PTA dataset. To produce Fig. 2 of *add link* we used this algorithm to search for a common uncorrelated red noise, and then reweighted the results according to the procedure described in Hourihane et. al 2023 (https://arxiv.org/abs/2212.06276). We also added jump proposals from the RN and DM hyperparameter prior distributions to help the sampler converge. For more details, see the python script *GWB_FourierLikelihood.py* in this same repository.

# %% [markdown]
# # Fourier vs time-domain: comparing apples-to-apples
#
# We prove now with a practical example that the time- and Fourier-domain formulations of the Fourier likelihood are analytically equivalent (within numerical accuracy) in the case of white noise and deterministic signals fixed.

# %%
# building the PTA objects (this time, both pta_0 and pta_fl have white noise and DM dip parameters fixed)
pta_0 = build_pta(psrs, inc_crn=False, fix_dip=True, logA_red=i_logA, gamma_red=i_gamma, logA_dm=i_logA, gamma_dm=i_gamma, log_kappa=i_logk)
pta_0.set_default_params(Wnoise_ml)
pta_fl = build_pta(psrs, fix_rn=False, fix_dm=False, fix_chrom=False, inc_crn=True, fix_dip=True, inc_dmdip=True, inc_chrom=True)
pta_fl.set_default_params(Wnoise_ml)
# Out:
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.P200.1380_efac to 1.1045950948818555
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.P217.1380_efac to 0.848194739410362
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.PS110.2487_efac to 0.9443048546615437
# INFO: enterprise.signals.signal_base: Setting J0030+0451_JBO.ROACH.1520_efac to 0.9184905449812792
# INFO: enterprise.signals.signal_base: Setting J0030+0451_LEAP.1396_efac to 1.4194567362018933
# INFO: enterprise.signals.signal_base: Setting J0030+0451_NRT.NUPPI.1484_efac to 0.776131390132143
# INFO: enterprise.signals.signal_base: Setting J0030+0451_NRT.NUPPI.1854_efac to 1.1089143495690343
# INFO: enterprise.signals.signal_base: Setting J0030+0451_WSRT.P2.1380_efac to 0.3381260667250748
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.P200.1380_log10_tnequad to -6.168262261771374
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.P217.1380_log10_tnequad to -7.898145381752085
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.PS110.2487_log10_tnequad to -6.263274196060782
# INFO: enterprise.signals.signal_base: Setting J0030+0451_JBO.ROACH.1520_log10_tnequad to -6.873679824259591
# INFO: enterprise.signals.signal_base: Setting J0030+0451_LEAP.1396_log10_tnequad to -7.035431021176787
# INFO: enterprise.signals.signal_base: Setting J0030+0451_NRT.NUPPI.1484_log10_tnequad to -7.984517962133032
# INFO: enterprise.signals.signal_base: Setting J0030+0451_NRT.NUPPI.1854_log10_tnequad to -6.4987472770497625
# INFO: enterprise.signals.signal_base: Setting J0030+0451_WSRT.P2.1380_log10_tnequad to -5.25577145703114
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.P200.1380_efac to 1.2810562728735235
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.P217.1380_efac to 1.2597018806785478
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.S110.2487_efac to 1.2266737944057213
# INFO: enterprise.signals.signal_base: Setting J0613-0200_JBO.ROACH.1520_efac to 0.911716114279691
# INFO: enterprise.signals.signal_base: Setting J0613-0200_LEAP.1396_efac to 0.6820842370183298
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.1484_efac to 0.8277857078402245
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.1854_efac to 0.7089371243040629
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.2539_efac to 0.8444149024880875
# INFO: enterprise.signals.signal_base: Setting J0613-0200_WSRT.P2.1380_efac to 1.2794135321268916
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.P200.1380_log10_tnequad to -7.688200368312655
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.P217.1380_log10_tnequad to -6.956714232036004
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.S110.2487_log10_tnequad to -6.526872383435261
# INFO: enterprise.signals.signal_base: Setting J0613-0200_JBO.ROACH.1520_log10_tnequad to -7.207738643749434
# INFO: enterprise.signals.signal_base: Setting J0613-0200_LEAP.1396_log10_tnequad to -6.3944038538275905
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.1484_log10_tnequad to -8.60165405615579
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.1854_log10_tnequad to -8.634364542894792
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.2539_log10_tnequad to -8.131395892976768
# INFO: enterprise.signals.signal_base: Setting J0613-0200_WSRT.P2.1380_log10_tnequad to -7.7779273400896365
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.P200.1380_efac to 1.4622887414114853
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.P217.1380_efac to 1.1182322606329167
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.S110.2487_efac to 1.2021518407383947
# INFO: enterprise.signals.signal_base: Setting J0751+1807_JBO.ROACH.1520_efac to 0.9659487293118227
# INFO: enterprise.signals.signal_base: Setting J0751+1807_LEAP.1396_efac to 0.9858262574040735
# INFO: enterprise.signals.signal_base: Setting J0751+1807_NRT.NUPPI.1484_efac to 0.8765546208048559
# INFO: enterprise.signals.signal_base: Setting J0751+1807_NRT.NUPPI.2539_efac to 0.8712565953680692
# INFO: enterprise.signals.signal_base: Setting J0751+1807_WSRT.P2.1380_efac to 1.0578633335599714
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.P200.1380_log10_tnequad to -5.855316110896133
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.P217.1380_log10_tnequad to -5.951730622301865
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.S110.2487_log10_tnequad to -8.273874757633164
# INFO: enterprise.signals.signal_base: Setting J0751+1807_JBO.ROACH.1520_log10_tnequad to -8.892936209777913
# INFO: enterprise.signals.signal_base: Setting J0751+1807_LEAP.1396_log10_tnequad to -7.228475518428845
# INFO: enterprise.signals.signal_base: Setting J0751+1807_NRT.NUPPI.1484_log10_tnequad to -7.240212548545826
# INFO: enterprise.signals.signal_base: Setting J0751+1807_NRT.NUPPI.2539_log10_tnequad to -6.521626337818643
# INFO: enterprise.signals.signal_base: Setting J0751+1807_WSRT.P2.1380_log10_tnequad to -6.760179341150843
# INFO: enterprise.signals.signal_base: Setting J0900-3144_JBO.ROACH.1520_efac to 1.04101013120358
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.1484_efac to 0.8506499833973288
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.1854_efac to 1.4944510649111937
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.2154_efac to 1.1280088187462487
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.2539_efac to 0.9074278562818382
# INFO: enterprise.signals.signal_base: Setting J0900-3144_JBO.ROACH.1520_log10_tnequad to -6.1579476020947235
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.1484_log10_tnequad to -6.1208882351205895
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.1854_log10_tnequad to -8.771532099848624
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.2154_log10_tnequad to -6.6692139276891975
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.2539_log10_tnequad to -8.857058345244642
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.P200.1380_efac to 1.0548133535433428
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.P217.1380_efac to 1.0877812691698507
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.S110.2487_efac to 0.989805594951363
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.S60.4857_efac to 0.8301538451582426
# INFO: enterprise.signals.signal_base: Setting J1012+5307_JBO.ROACH.1520_efac to 0.9641677541515948
# INFO: enterprise.signals.signal_base: Setting J1012+5307_LEAP.1396_efac to 1.4332993699844783
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.1484_efac to 0.8472184300814208
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.1854_efac to 0.8143047394107772
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.2539_efac to 0.7671972870699303
# INFO: enterprise.signals.signal_base: Setting J1012+5307_WSRT.P2.1380_efac to 1.237984987345866
# INFO: enterprise.signals.signal_base: Setting J1012+5307_WSRT.P2.350_efac to 1.2892671667785593
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.P200.1380_log10_tnequad to -6.240183097594486
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.P217.1380_log10_tnequad to -6.804387306350895
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.S110.2487_log10_tnequad to -5.70344505119584
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.S60.4857_log10_tnequad to -8.674275925215627
# INFO: enterprise.signals.signal_base: Setting J1012+5307_JBO.ROACH.1520_log10_tnequad to -8.49205268487396
# INFO: enterprise.signals.signal_base: Setting J1012+5307_LEAP.1396_log10_tnequad to -6.681502406231853
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.1484_log10_tnequad to -8.859715211778916
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.1854_log10_tnequad to -6.240703159669776
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.2539_log10_tnequad to -7.236433417005013
# INFO: enterprise.signals.signal_base: Setting J1012+5307_WSRT.P2.1380_log10_tnequad to -7.693529095894691
# INFO: enterprise.signals.signal_base: Setting J1012+5307_WSRT.P2.350_log10_tnequad to -8.563979070953891
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.P200.1380_efac to 0.8102206481490057
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.P217.1380_efac to 0.7858128904591491
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.S110.2487_efac to 0.879606018512383
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.S60.4857_efac to 1.1737541790871822
# INFO: enterprise.signals.signal_base: Setting J1022+1001_JBO.ROACH.1520_efac to 1.0747453048700975
# INFO: enterprise.signals.signal_base: Setting J1022+1001_LEAP.1396_efac to 2.438256888182125
# INFO: enterprise.signals.signal_base: Setting J1022+1001_NRT.NUPPI.1484_efac to 0.805516529751389
# INFO: enterprise.signals.signal_base: Setting J1022+1001_WSRT.P2.1380_efac to 1.0806590482719904
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.P200.1380_log10_tnequad to -6.572227821559285
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.P217.1380_log10_tnequad to -7.005589378023857
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.S110.2487_log10_tnequad to -6.391685700921404
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.S60.4857_log10_tnequad to -5.6713037903220505
# INFO: enterprise.signals.signal_base: Setting J1022+1001_JBO.ROACH.1520_log10_tnequad to -5.826146883391521
# INFO: enterprise.signals.signal_base: Setting J1022+1001_LEAP.1396_log10_tnequad to -8.63537066059122
# INFO: enterprise.signals.signal_base: Setting J1022+1001_NRT.NUPPI.1484_log10_tnequad to -6.208441744577778
# INFO: enterprise.signals.signal_base: Setting J1022+1001_WSRT.P2.1380_log10_tnequad to -5.748242625477178
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.P200.1380_efac to 0.9551974352791707
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.P217.1380_efac to 0.9258318800843921
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.S110.2487_efac to 0.8396735963799056
# INFO: enterprise.signals.signal_base: Setting J1024-0719_JBO.ROACH.1520_efac to 0.9434863523119911
# INFO: enterprise.signals.signal_base: Setting J1024-0719_LEAP.1396_efac to 1.1523801155580489
# INFO: enterprise.signals.signal_base: Setting J1024-0719_NRT.NUPPI.1484_efac to 0.7687856834625707
# INFO: enterprise.signals.signal_base: Setting J1024-0719_NRT.NUPPI.2539_efac to 0.8045230724764365
# INFO: enterprise.signals.signal_base: Setting J1024-0719_WSRT.P2.1380_efac to 0.4653006137768964
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.P200.1380_log10_tnequad to -7.05065179837003
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.P217.1380_log10_tnequad to -6.189856602824119
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.S110.2487_log10_tnequad to -5.346016302576432
# INFO: enterprise.signals.signal_base: Setting J1024-0719_JBO.ROACH.1520_log10_tnequad to -8.21586325008337
# INFO: enterprise.signals.signal_base: Setting J1024-0719_LEAP.1396_log10_tnequad to -6.290103368658607
# INFO: enterprise.signals.signal_base: Setting J1024-0719_NRT.NUPPI.1484_log10_tnequad to -7.32549311640761
# INFO: enterprise.signals.signal_base: Setting J1024-0719_NRT.NUPPI.2539_log10_tnequad to -8.106099547840559
# INFO: enterprise.signals.signal_base: Setting J1024-0719_WSRT.P2.1380_log10_tnequad to -5.694096730161006
# INFO: enterprise.signals.signal_base: Setting J1455-3330_JBO.ROACH.1520_efac to 0.8043700135371057
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.1484_efac to 0.8407432349339051
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.1854_efac to 0.8338079763067537
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.2539_efac to 0.8883363918996182
# INFO: enterprise.signals.signal_base: Setting J1455-3330_JBO.ROACH.1520_log10_tnequad to -8.694817396061016
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.1484_log10_tnequad to -8.47992369819152
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.1854_log10_tnequad to -5.868863195311095
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.2539_log10_tnequad to -6.287320180876826
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.P200.1380_efac to 0.9165710995742749
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.P217.1380_efac to 1.7551021055815608
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.S110.2487_efac to 1.1549168980036049
# INFO: enterprise.signals.signal_base: Setting J1600-3053_JBO.ROACH.1520_efac to 1.217854326425572
# INFO: enterprise.signals.signal_base: Setting J1600-3053_LEAP.1396_efac to 1.9527327109252122
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.1484_efac to 0.7353004001394867
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.1854_efac to 0.9123422835055031
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.2154_efac to 0.749663602721091
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.2539_efac to 0.8038809724822832
# INFO: enterprise.signals.signal_base: Setting J1600-3053_WSRT.P2.1380_efac to 0.9704307198506573
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.P200.1380_log10_tnequad to -8.78681028514216
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.P217.1380_log10_tnequad to -5.519052538898048
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.S110.2487_log10_tnequad to -7.59331811415248
# INFO: enterprise.signals.signal_base: Setting J1600-3053_JBO.ROACH.1520_log10_tnequad to -6.8630253018403256
# INFO: enterprise.signals.signal_base: Setting J1600-3053_LEAP.1396_log10_tnequad to -8.096990503062509
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.1484_log10_tnequad to -6.9799998357772095
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.1854_log10_tnequad to -8.120215061110759
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.2154_log10_tnequad to -8.795040948819464
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.2539_log10_tnequad to -7.793228746717177
# INFO: enterprise.signals.signal_base: Setting J1600-3053_WSRT.P2.1380_log10_tnequad to -6.63125782756769
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.P200.1380_efac to 1.6740103438387088
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.P217.1380_efac to 1.0356321999126166
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.S110.2487_efac to 1.344823590532148
# INFO: enterprise.signals.signal_base: Setting J1640+2224_JBO.ROACH.1520_efac to 1.0900889895596009
# INFO: enterprise.signals.signal_base: Setting J1640+2224_LEAP.1396_efac to 1.0755152580227818
# INFO: enterprise.signals.signal_base: Setting J1640+2224_NRT.NUPPI.1484_efac to 0.9349544896349673
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.P200.1380_log10_tnequad to -8.119469937696858
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.P217.1380_log10_tnequad to -8.361131309787513
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.S110.2487_log10_tnequad to -8.33652279211746
# INFO: enterprise.signals.signal_base: Setting J1640+2224_JBO.ROACH.1520_log10_tnequad to -6.89888899120869
# INFO: enterprise.signals.signal_base: Setting J1640+2224_LEAP.1396_log10_tnequad to -7.3394633596342995
# INFO: enterprise.signals.signal_base: Setting J1640+2224_NRT.NUPPI.1484_log10_tnequad to -7.946053186812969
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.P200.1380_efac to 1.412374726303919
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.P217.1380_efac to 1.1826730155965852
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.S110.2487_efac to 1.843610252576271
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.S60.4857_efac to 0.9566210128555996
# INFO: enterprise.signals.signal_base: Setting J1713+0747_JBO.MK2.1520_efac to 0.8778418556697566
# INFO: enterprise.signals.signal_base: Setting J1713+0747_JBO.ROACH.1520_efac to 0.8794972097058603
# INFO: enterprise.signals.signal_base: Setting J1713+0747_LEAP.1396_efac to 1.552862675531769
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.1484_efac to 0.7896503325063164
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.1854_efac to 0.7079678541925291
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.2539_efac to 0.7731047657187958
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.1380_efac to 1.0345911103112715
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.2273_efac to 0.8427914809395443
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.350_efac to 0.898914858648177
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.P200.1380_log10_tnequad to -6.649000741215544
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.P217.1380_log10_tnequad to -6.6593602574637805
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.S110.2487_log10_tnequad to -7.9772772266290275
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.S60.4857_log10_tnequad to -8.312222023615337
# INFO: enterprise.signals.signal_base: Setting J1713+0747_JBO.MK2.1520_log10_tnequad to -8.095181552632685
# INFO: enterprise.signals.signal_base: Setting J1713+0747_JBO.ROACH.1520_log10_tnequad to -6.615228034705099
# INFO: enterprise.signals.signal_base: Setting J1713+0747_LEAP.1396_log10_tnequad to -6.7185150489060375
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.1484_log10_tnequad to -7.124620438769816
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.1854_log10_tnequad to -8.520459384443132
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.2539_log10_tnequad to -6.868562726735876
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.1380_log10_tnequad to -6.9716719287703555
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.2273_log10_tnequad to -6.676656824013697
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.350_log10_tnequad to -8.972410387384546
# INFO: enterprise.signals.signal_base: Setting J1730-2304_JBO.ROACH.1520_efac to 1.0966895598937743
# INFO: enterprise.signals.signal_base: Setting J1730-2304_NRT.NUPPI.1484_efac to 0.8936515336010582
# INFO: enterprise.signals.signal_base: Setting J1730-2304_NRT.NUPPI.2539_efac to 0.82955546014866
# INFO: enterprise.signals.signal_base: Setting J1730-2304_JBO.ROACH.1520_log10_tnequad to -8.76732339089998
# INFO: enterprise.signals.signal_base: Setting J1730-2304_NRT.NUPPI.1484_log10_tnequad to -7.092912342511541
# INFO: enterprise.signals.signal_base: Setting J1730-2304_NRT.NUPPI.2539_log10_tnequad to -8.070483707308561
# INFO: enterprise.signals.signal_base: Setting J1738+0333_EFF.P200.1380_efac to 1.2329115324118975
# INFO: enterprise.signals.signal_base: Setting J1738+0333_EFF.P217.1380_efac to 0.8867280280191301
# INFO: enterprise.signals.signal_base: Setting J1738+0333_JBO.ROACH.1520_efac to 0.7472756385097318
# INFO: enterprise.signals.signal_base: Setting J1738+0333_NRT.NUPPI.1484_efac to 0.8613738492525165
# INFO: enterprise.signals.signal_base: Setting J1738+0333_WSRT.P2.1380_efac to 1.1112003518112685
# INFO: enterprise.signals.signal_base: Setting J1738+0333_EFF.P200.1380_log10_tnequad to -6.79109245509378
# INFO: enterprise.signals.signal_base: Setting J1738+0333_EFF.P217.1380_log10_tnequad to -7.93640722539657
# INFO: enterprise.signals.signal_base: Setting J1738+0333_JBO.ROACH.1520_log10_tnequad to -5.43250967829
# INFO: enterprise.signals.signal_base: Setting J1738+0333_NRT.NUPPI.1484_log10_tnequad to -7.826039383135421
# INFO: enterprise.signals.signal_base: Setting J1738+0333_WSRT.P2.1380_log10_tnequad to -8.662202710812908
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.P200.1380_efac to 1.5289889739981626
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.P217.1380_efac to 1.2771057723574064
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.S110.2487_efac to 1.244705701316738
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.S60.4857_efac to 1.0561167945451462
# INFO: enterprise.signals.signal_base: Setting J1744-1134_JBO.ROACH.1520_efac to 1.1363656211662838
# INFO: enterprise.signals.signal_base: Setting J1744-1134_LEAP.1396_efac to 1.3136587135168925
# INFO: enterprise.signals.signal_base: Setting J1744-1134_NRT.NUPPI.1484_efac to 0.8171455527990248
# INFO: enterprise.signals.signal_base: Setting J1744-1134_NRT.NUPPI.2539_efac to 0.6214279693404747
# INFO: enterprise.signals.signal_base: Setting J1744-1134_WSRT.P2.1380_efac to 1.2098338519224716
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.P200.1380_log10_tnequad to -8.076864368319155
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.P217.1380_log10_tnequad to -7.778377010704876
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.S110.2487_log10_tnequad to -6.53903945008975
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.S60.4857_log10_tnequad to -7.257195389387301
# INFO: enterprise.signals.signal_base: Setting J1744-1134_JBO.ROACH.1520_log10_tnequad to -6.3815473236602775
# INFO: enterprise.signals.signal_base: Setting J1744-1134_LEAP.1396_log10_tnequad to -6.478777690017408
# INFO: enterprise.signals.signal_base: Setting J1744-1134_NRT.NUPPI.1484_log10_tnequad to -6.727670528542976
# INFO: enterprise.signals.signal_base: Setting J1744-1134_NRT.NUPPI.2539_log10_tnequad to -6.520348996009733
# INFO: enterprise.signals.signal_base: Setting J1744-1134_WSRT.P2.1380_log10_tnequad to -6.695781710027594
# INFO: enterprise.signals.signal_base: Setting J1751-2857_JBO.ROACH.1520_efac to 0.7549920950094138
# INFO: enterprise.signals.signal_base: Setting J1751-2857_NRT.NUPPI.1484_efac to 0.7531123951282895
# INFO: enterprise.signals.signal_base: Setting J1751-2857_JBO.ROACH.1520_log10_tnequad to -8.984319052277996
# INFO: enterprise.signals.signal_base: Setting J1751-2857_NRT.NUPPI.1484_log10_tnequad to -8.842148621404872
# INFO: enterprise.signals.signal_base: Setting J1801-1417_JBO.ROACH.1520_efac to 0.9864350427630586
# INFO: enterprise.signals.signal_base: Setting J1801-1417_NRT.NUPPI.1484_efac to 0.7483157602884402
# INFO: enterprise.signals.signal_base: Setting J1801-1417_JBO.ROACH.1520_log10_tnequad to -6.261181331261443
# INFO: enterprise.signals.signal_base: Setting J1801-1417_NRT.NUPPI.1484_log10_tnequad to -6.117048727714347
# INFO: enterprise.signals.signal_base: Setting J1804-2717_JBO.ROACH.1520_efac to 1.0057404787686226
# INFO: enterprise.signals.signal_base: Setting J1804-2717_NRT.NUPPI.1484_efac to 0.8049270400445149
# INFO: enterprise.signals.signal_base: Setting J1804-2717_JBO.ROACH.1520_log10_tnequad to -8.517548525232066
# INFO: enterprise.signals.signal_base: Setting J1804-2717_NRT.NUPPI.1484_log10_tnequad to -7.738473879868597
# INFO: enterprise.signals.signal_base: Setting J1843-1113_EFF.P217.1380_efac to 1.1814583391980884
# INFO: enterprise.signals.signal_base: Setting J1843-1113_EFF.S110.2487_efac to 0.8510196074666396
# INFO: enterprise.signals.signal_base: Setting J1843-1113_JBO.ROACH.1520_efac to 0.5085959354688436
# INFO: enterprise.signals.signal_base: Setting J1843-1113_NRT.NUPPI.1484_efac to 0.7483857925666096
# INFO: enterprise.signals.signal_base: Setting J1843-1113_WSRT.P2.1380_efac to 1.0406588880071412
# INFO: enterprise.signals.signal_base: Setting J1843-1113_EFF.P217.1380_log10_tnequad to -7.348379374130354
# INFO: enterprise.signals.signal_base: Setting J1843-1113_EFF.S110.2487_log10_tnequad to -7.178804349666641
# INFO: enterprise.signals.signal_base: Setting J1843-1113_JBO.ROACH.1520_log10_tnequad to -5.297139966908785
# INFO: enterprise.signals.signal_base: Setting J1843-1113_NRT.NUPPI.1484_log10_tnequad to -8.20133231501511
# INFO: enterprise.signals.signal_base: Setting J1843-1113_WSRT.P2.1380_log10_tnequad to -6.567219495870018
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.P200.1380_efac to 0.8903961781606221
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.P217.1380_efac to 0.5727944719143326
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.S110.2487_efac to 0.8872282802497014
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.S60.4857_efac to 0.7349637319778864
# INFO: enterprise.signals.signal_base: Setting J1857+0943_JBO.ROACH.1520_efac to 1.2238336779590848
# INFO: enterprise.signals.signal_base: Setting J1857+0943_LEAP.1396_efac to 1.5409148049950512
# INFO: enterprise.signals.signal_base: Setting J1857+0943_NRT.NUPPI.1484_efac to 0.9416000131448992
# INFO: enterprise.signals.signal_base: Setting J1857+0943_NRT.NUPPI.2539_efac to 0.9509516872455311
# INFO: enterprise.signals.signal_base: Setting J1857+0943_WSRT.P2.1380_efac to 0.9497468011319526
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.P200.1380_log10_tnequad to -8.08507027056367
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.P217.1380_log10_tnequad to -5.651476519327127
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.S110.2487_log10_tnequad to -5.5312698143074845
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.S60.4857_log10_tnequad to -8.426628290626866
# INFO: enterprise.signals.signal_base: Setting J1857+0943_JBO.ROACH.1520_log10_tnequad to -6.135956765069297
# INFO: enterprise.signals.signal_base: Setting J1857+0943_LEAP.1396_log10_tnequad to -6.855223837221721
# INFO: enterprise.signals.signal_base: Setting J1857+0943_NRT.NUPPI.1484_log10_tnequad to -8.900236976699127
# INFO: enterprise.signals.signal_base: Setting J1857+0943_NRT.NUPPI.2539_log10_tnequad to -8.33485330361282
# INFO: enterprise.signals.signal_base: Setting J1857+0943_WSRT.P2.1380_log10_tnequad to -8.621053689913959
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.1484_efac to 0.8540704265946855
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.1854_efac to 0.7676705441810963
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.2154_efac to 1.03247195323751
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.2539_efac to 0.7010197803207379
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.1484_log10_tnequad to -7.415073878834863
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.1854_log10_tnequad to -7.120859176440731
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.2154_log10_tnequad to -7.230582195698377
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.2539_log10_tnequad to -6.971700069604973
# INFO: enterprise.signals.signal_base: Setting J1910+1256_JBO.ROACH.1520_efac to 1.0605708987634797
# INFO: enterprise.signals.signal_base: Setting J1910+1256_NRT.NUPPI.1484_efac to 0.8345119172671124
# INFO: enterprise.signals.signal_base: Setting J1910+1256_JBO.ROACH.1520_log10_tnequad to -8.60288324441584
# INFO: enterprise.signals.signal_base: Setting J1910+1256_NRT.NUPPI.1484_log10_tnequad to -6.560712227869687
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.P200.1380_efac to 0.8761134222727486
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.P217.1380_efac to 1.4282541670316486
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.S110.2487_efac to 1.6558234534679714
# INFO: enterprise.signals.signal_base: Setting J1911+1347_JBO.ROACH.1520_efac to 0.8120162030722926
# INFO: enterprise.signals.signal_base: Setting J1911+1347_NRT.NUPPI.1484_efac to 0.8145191417597308
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.P200.1380_log10_tnequad to -6.325898247530114
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.P217.1380_log10_tnequad to -8.972867072178717
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.S110.2487_log10_tnequad to -5.8910997224670405
# INFO: enterprise.signals.signal_base: Setting J1911+1347_JBO.ROACH.1520_log10_tnequad to -5.504056196974953
# INFO: enterprise.signals.signal_base: Setting J1911+1347_NRT.NUPPI.1484_log10_tnequad to -8.815757478736355
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.P200.1380_efac to 0.911571024305496
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.P217.1380_efac to 1.1332353140352633
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.S110.2487_efac to 0.5276154326065083
# INFO: enterprise.signals.signal_base: Setting J1918-0642_JBO.ROACH.1520_efac to 0.9655238565741925
# INFO: enterprise.signals.signal_base: Setting J1918-0642_LEAP.1396_efac to 0.6781781812273364
# INFO: enterprise.signals.signal_base: Setting J1918-0642_NRT.NUPPI.1484_efac to 0.831041493837829
# INFO: enterprise.signals.signal_base: Setting J1918-0642_WSRT.P2.1380_efac to 0.9493532309055206
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.P200.1380_log10_tnequad to -6.339692244024356
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.P217.1380_log10_tnequad to -7.9507971426473105
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.S110.2487_log10_tnequad to -5.583677452793728
# INFO: enterprise.signals.signal_base: Setting J1918-0642_JBO.ROACH.1520_log10_tnequad to -6.332914721246314
# INFO: enterprise.signals.signal_base: Setting J1918-0642_LEAP.1396_log10_tnequad to -5.796154707117647
# INFO: enterprise.signals.signal_base: Setting J1918-0642_NRT.NUPPI.1484_log10_tnequad to -6.636962947462052
# INFO: enterprise.signals.signal_base: Setting J1918-0642_WSRT.P2.1380_log10_tnequad to -7.45893781848895
# INFO: enterprise.signals.signal_base: Setting J2124-3358_JBO.ROACH.1520_efac to 1.3225391415374796
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.1484_efac to 0.8358609453728573
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.1854_efac to 0.808915114390453
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.2154_efac to 1.128419743531647
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.2539_efac to 0.6632723665048084
# INFO: enterprise.signals.signal_base: Setting J2124-3358_JBO.ROACH.1520_log10_tnequad to -8.02686408638112
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.1484_log10_tnequad to -8.868578577184497
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.1854_log10_tnequad to -5.254878544747536
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.2154_log10_tnequad to -7.4274298640233125
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.2539_log10_tnequad to -5.366358828495574
# INFO: enterprise.signals.signal_base: Setting J2322+2057_EFF.P217.1380_efac to 1.2087043553497132
# INFO: enterprise.signals.signal_base: Setting J2322+2057_JBO.ROACH.1520_efac to 0.9610659725859465
# INFO: enterprise.signals.signal_base: Setting J2322+2057_NRT.NUPPI.1484_efac to 0.8809550106099319
# INFO: enterprise.signals.signal_base: Setting J2322+2057_EFF.P217.1380_log10_tnequad to -6.508521806272974
# INFO: enterprise.signals.signal_base: Setting J2322+2057_JBO.ROACH.1520_log10_tnequad to -6.054868484868762
# INFO: enterprise.signals.signal_base: Setting J2322+2057_NRT.NUPPI.1484_log10_tnequad to -8.583883932763115
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.P200.1380_efac to 1.1045950948818555
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.P217.1380_efac to 0.848194739410362
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.PS110.2487_efac to 0.9443048546615437
# INFO: enterprise.signals.signal_base: Setting J0030+0451_JBO.ROACH.1520_efac to 0.9184905449812792
# INFO: enterprise.signals.signal_base: Setting J0030+0451_LEAP.1396_efac to 1.4194567362018933
# INFO: enterprise.signals.signal_base: Setting J0030+0451_NRT.NUPPI.1484_efac to 0.776131390132143
# INFO: enterprise.signals.signal_base: Setting J0030+0451_NRT.NUPPI.1854_efac to 1.1089143495690343
# INFO: enterprise.signals.signal_base: Setting J0030+0451_WSRT.P2.1380_efac to 0.3381260667250748
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.P200.1380_log10_tnequad to -6.168262261771374
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.P217.1380_log10_tnequad to -7.898145381752085
# INFO: enterprise.signals.signal_base: Setting J0030+0451_EFF.PS110.2487_log10_tnequad to -6.263274196060782
# INFO: enterprise.signals.signal_base: Setting J0030+0451_JBO.ROACH.1520_log10_tnequad to -6.873679824259591
# INFO: enterprise.signals.signal_base: Setting J0030+0451_LEAP.1396_log10_tnequad to -7.035431021176787
# INFO: enterprise.signals.signal_base: Setting J0030+0451_NRT.NUPPI.1484_log10_tnequad to -7.984517962133032
# INFO: enterprise.signals.signal_base: Setting J0030+0451_NRT.NUPPI.1854_log10_tnequad to -6.4987472770497625
# INFO: enterprise.signals.signal_base: Setting J0030+0451_WSRT.P2.1380_log10_tnequad to -5.25577145703114
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.P200.1380_efac to 1.2810562728735235
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.P217.1380_efac to 1.2597018806785478
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.S110.2487_efac to 1.2266737944057213
# INFO: enterprise.signals.signal_base: Setting J0613-0200_JBO.ROACH.1520_efac to 0.911716114279691
# INFO: enterprise.signals.signal_base: Setting J0613-0200_LEAP.1396_efac to 0.6820842370183298
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.1484_efac to 0.8277857078402245
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.1854_efac to 0.7089371243040629
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.2539_efac to 0.8444149024880875
# INFO: enterprise.signals.signal_base: Setting J0613-0200_WSRT.P2.1380_efac to 1.2794135321268916
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.P200.1380_log10_tnequad to -7.688200368312655
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.P217.1380_log10_tnequad to -6.956714232036004
# INFO: enterprise.signals.signal_base: Setting J0613-0200_EFF.S110.2487_log10_tnequad to -6.526872383435261
# INFO: enterprise.signals.signal_base: Setting J0613-0200_JBO.ROACH.1520_log10_tnequad to -7.207738643749434
# INFO: enterprise.signals.signal_base: Setting J0613-0200_LEAP.1396_log10_tnequad to -6.3944038538275905
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.1484_log10_tnequad to -8.60165405615579
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.1854_log10_tnequad to -8.634364542894792
# INFO: enterprise.signals.signal_base: Setting J0613-0200_NRT.NUPPI.2539_log10_tnequad to -8.131395892976768
# INFO: enterprise.signals.signal_base: Setting J0613-0200_WSRT.P2.1380_log10_tnequad to -7.7779273400896365
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.P200.1380_efac to 1.4622887414114853
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.P217.1380_efac to 1.1182322606329167
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.S110.2487_efac to 1.2021518407383947
# INFO: enterprise.signals.signal_base: Setting J0751+1807_JBO.ROACH.1520_efac to 0.9659487293118227
# INFO: enterprise.signals.signal_base: Setting J0751+1807_LEAP.1396_efac to 0.9858262574040735
# INFO: enterprise.signals.signal_base: Setting J0751+1807_NRT.NUPPI.1484_efac to 0.8765546208048559
# INFO: enterprise.signals.signal_base: Setting J0751+1807_NRT.NUPPI.2539_efac to 0.8712565953680692
# INFO: enterprise.signals.signal_base: Setting J0751+1807_WSRT.P2.1380_efac to 1.0578633335599714
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.P200.1380_log10_tnequad to -5.855316110896133
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.P217.1380_log10_tnequad to -5.951730622301865
# INFO: enterprise.signals.signal_base: Setting J0751+1807_EFF.S110.2487_log10_tnequad to -8.273874757633164
# INFO: enterprise.signals.signal_base: Setting J0751+1807_JBO.ROACH.1520_log10_tnequad to -8.892936209777913
# INFO: enterprise.signals.signal_base: Setting J0751+1807_LEAP.1396_log10_tnequad to -7.228475518428845
# INFO: enterprise.signals.signal_base: Setting J0751+1807_NRT.NUPPI.1484_log10_tnequad to -7.240212548545826
# INFO: enterprise.signals.signal_base: Setting J0751+1807_NRT.NUPPI.2539_log10_tnequad to -6.521626337818643
# INFO: enterprise.signals.signal_base: Setting J0751+1807_WSRT.P2.1380_log10_tnequad to -6.760179341150843
# INFO: enterprise.signals.signal_base: Setting J0900-3144_JBO.ROACH.1520_efac to 1.04101013120358
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.1484_efac to 0.8506499833973288
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.1854_efac to 1.4944510649111937
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.2154_efac to 1.1280088187462487
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.2539_efac to 0.9074278562818382
# INFO: enterprise.signals.signal_base: Setting J0900-3144_JBO.ROACH.1520_log10_tnequad to -6.1579476020947235
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.1484_log10_tnequad to -6.1208882351205895
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.1854_log10_tnequad to -8.771532099848624
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.2154_log10_tnequad to -6.6692139276891975
# INFO: enterprise.signals.signal_base: Setting J0900-3144_NRT.NUPPI.2539_log10_tnequad to -8.857058345244642
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.P200.1380_efac to 1.0548133535433428
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.P217.1380_efac to 1.0877812691698507
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.S110.2487_efac to 0.989805594951363
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.S60.4857_efac to 0.8301538451582426
# INFO: enterprise.signals.signal_base: Setting J1012+5307_JBO.ROACH.1520_efac to 0.9641677541515948
# INFO: enterprise.signals.signal_base: Setting J1012+5307_LEAP.1396_efac to 1.4332993699844783
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.1484_efac to 0.8472184300814208
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.1854_efac to 0.8143047394107772
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.2539_efac to 0.7671972870699303
# INFO: enterprise.signals.signal_base: Setting J1012+5307_WSRT.P2.1380_efac to 1.237984987345866
# INFO: enterprise.signals.signal_base: Setting J1012+5307_WSRT.P2.350_efac to 1.2892671667785593
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.P200.1380_log10_tnequad to -6.240183097594486
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.P217.1380_log10_tnequad to -6.804387306350895
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.S110.2487_log10_tnequad to -5.70344505119584
# INFO: enterprise.signals.signal_base: Setting J1012+5307_EFF.S60.4857_log10_tnequad to -8.674275925215627
# INFO: enterprise.signals.signal_base: Setting J1012+5307_JBO.ROACH.1520_log10_tnequad to -8.49205268487396
# INFO: enterprise.signals.signal_base: Setting J1012+5307_LEAP.1396_log10_tnequad to -6.681502406231853
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.1484_log10_tnequad to -8.859715211778916
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.1854_log10_tnequad to -6.240703159669776
# INFO: enterprise.signals.signal_base: Setting J1012+5307_NRT.NUPPI.2539_log10_tnequad to -7.236433417005013
# INFO: enterprise.signals.signal_base: Setting J1012+5307_WSRT.P2.1380_log10_tnequad to -7.693529095894691
# INFO: enterprise.signals.signal_base: Setting J1012+5307_WSRT.P2.350_log10_tnequad to -8.563979070953891
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.P200.1380_efac to 0.8102206481490057
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.P217.1380_efac to 0.7858128904591491
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.S110.2487_efac to 0.879606018512383
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.S60.4857_efac to 1.1737541790871822
# INFO: enterprise.signals.signal_base: Setting J1022+1001_JBO.ROACH.1520_efac to 1.0747453048700975
# INFO: enterprise.signals.signal_base: Setting J1022+1001_LEAP.1396_efac to 2.438256888182125
# INFO: enterprise.signals.signal_base: Setting J1022+1001_NRT.NUPPI.1484_efac to 0.805516529751389
# INFO: enterprise.signals.signal_base: Setting J1022+1001_WSRT.P2.1380_efac to 1.0806590482719904
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.P200.1380_log10_tnequad to -6.572227821559285
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.P217.1380_log10_tnequad to -7.005589378023857
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.S110.2487_log10_tnequad to -6.391685700921404
# INFO: enterprise.signals.signal_base: Setting J1022+1001_EFF.S60.4857_log10_tnequad to -5.6713037903220505
# INFO: enterprise.signals.signal_base: Setting J1022+1001_JBO.ROACH.1520_log10_tnequad to -5.826146883391521
# INFO: enterprise.signals.signal_base: Setting J1022+1001_LEAP.1396_log10_tnequad to -8.63537066059122
# INFO: enterprise.signals.signal_base: Setting J1022+1001_NRT.NUPPI.1484_log10_tnequad to -6.208441744577778
# INFO: enterprise.signals.signal_base: Setting J1022+1001_WSRT.P2.1380_log10_tnequad to -5.748242625477178
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.P200.1380_efac to 0.9551974352791707
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.P217.1380_efac to 0.9258318800843921
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.S110.2487_efac to 0.8396735963799056
# INFO: enterprise.signals.signal_base: Setting J1024-0719_JBO.ROACH.1520_efac to 0.9434863523119911
# INFO: enterprise.signals.signal_base: Setting J1024-0719_LEAP.1396_efac to 1.1523801155580489
# INFO: enterprise.signals.signal_base: Setting J1024-0719_NRT.NUPPI.1484_efac to 0.7687856834625707
# INFO: enterprise.signals.signal_base: Setting J1024-0719_NRT.NUPPI.2539_efac to 0.8045230724764365
# INFO: enterprise.signals.signal_base: Setting J1024-0719_WSRT.P2.1380_efac to 0.4653006137768964
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.P200.1380_log10_tnequad to -7.05065179837003
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.P217.1380_log10_tnequad to -6.189856602824119
# INFO: enterprise.signals.signal_base: Setting J1024-0719_EFF.S110.2487_log10_tnequad to -5.346016302576432
# INFO: enterprise.signals.signal_base: Setting J1024-0719_JBO.ROACH.1520_log10_tnequad to -8.21586325008337
# INFO: enterprise.signals.signal_base: Setting J1024-0719_LEAP.1396_log10_tnequad to -6.290103368658607
# INFO: enterprise.signals.signal_base: Setting J1024-0719_NRT.NUPPI.1484_log10_tnequad to -7.32549311640761
# INFO: enterprise.signals.signal_base: Setting J1024-0719_NRT.NUPPI.2539_log10_tnequad to -8.106099547840559
# INFO: enterprise.signals.signal_base: Setting J1024-0719_WSRT.P2.1380_log10_tnequad to -5.694096730161006
# INFO: enterprise.signals.signal_base: Setting J1455-3330_JBO.ROACH.1520_efac to 0.8043700135371057
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.1484_efac to 0.8407432349339051
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.1854_efac to 0.8338079763067537
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.2539_efac to 0.8883363918996182
# INFO: enterprise.signals.signal_base: Setting J1455-3330_JBO.ROACH.1520_log10_tnequad to -8.694817396061016
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.1484_log10_tnequad to -8.47992369819152
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.1854_log10_tnequad to -5.868863195311095
# INFO: enterprise.signals.signal_base: Setting J1455-3330_NRT.NUPPI.2539_log10_tnequad to -6.287320180876826
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.P200.1380_efac to 0.9165710995742749
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.P217.1380_efac to 1.7551021055815608
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.S110.2487_efac to 1.1549168980036049
# INFO: enterprise.signals.signal_base: Setting J1600-3053_JBO.ROACH.1520_efac to 1.217854326425572
# INFO: enterprise.signals.signal_base: Setting J1600-3053_LEAP.1396_efac to 1.9527327109252122
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.1484_efac to 0.7353004001394867
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.1854_efac to 0.9123422835055031
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.2154_efac to 0.749663602721091
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.2539_efac to 0.8038809724822832
# INFO: enterprise.signals.signal_base: Setting J1600-3053_WSRT.P2.1380_efac to 0.9704307198506573
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.P200.1380_log10_tnequad to -8.78681028514216
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.P217.1380_log10_tnequad to -5.519052538898048
# INFO: enterprise.signals.signal_base: Setting J1600-3053_EFF.S110.2487_log10_tnequad to -7.59331811415248
# INFO: enterprise.signals.signal_base: Setting J1600-3053_JBO.ROACH.1520_log10_tnequad to -6.8630253018403256
# INFO: enterprise.signals.signal_base: Setting J1600-3053_LEAP.1396_log10_tnequad to -8.096990503062509
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.1484_log10_tnequad to -6.9799998357772095
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.1854_log10_tnequad to -8.120215061110759
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.2154_log10_tnequad to -8.795040948819464
# INFO: enterprise.signals.signal_base: Setting J1600-3053_NRT.NUPPI.2539_log10_tnequad to -7.793228746717177
# INFO: enterprise.signals.signal_base: Setting J1600-3053_WSRT.P2.1380_log10_tnequad to -6.63125782756769
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.P200.1380_efac to 1.6740103438387088
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.P217.1380_efac to 1.0356321999126166
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.S110.2487_efac to 1.344823590532148
# INFO: enterprise.signals.signal_base: Setting J1640+2224_JBO.ROACH.1520_efac to 1.0900889895596009
# INFO: enterprise.signals.signal_base: Setting J1640+2224_LEAP.1396_efac to 1.0755152580227818
# INFO: enterprise.signals.signal_base: Setting J1640+2224_NRT.NUPPI.1484_efac to 0.9349544896349673
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.P200.1380_log10_tnequad to -8.119469937696858
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.P217.1380_log10_tnequad to -8.361131309787513
# INFO: enterprise.signals.signal_base: Setting J1640+2224_EFF.S110.2487_log10_tnequad to -8.33652279211746
# INFO: enterprise.signals.signal_base: Setting J1640+2224_JBO.ROACH.1520_log10_tnequad to -6.89888899120869
# INFO: enterprise.signals.signal_base: Setting J1640+2224_LEAP.1396_log10_tnequad to -7.3394633596342995
# INFO: enterprise.signals.signal_base: Setting J1640+2224_NRT.NUPPI.1484_log10_tnequad to -7.946053186812969
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.P200.1380_efac to 1.412374726303919
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.P217.1380_efac to 1.1826730155965852
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.S110.2487_efac to 1.843610252576271
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.S60.4857_efac to 0.9566210128555996
# INFO: enterprise.signals.signal_base: Setting J1713+0747_JBO.MK2.1520_efac to 0.8778418556697566
# INFO: enterprise.signals.signal_base: Setting J1713+0747_JBO.ROACH.1520_efac to 0.8794972097058603
# INFO: enterprise.signals.signal_base: Setting J1713+0747_LEAP.1396_efac to 1.552862675531769
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.1484_efac to 0.7896503325063164
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.1854_efac to 0.7079678541925291
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.2539_efac to 0.7731047657187958
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.1380_efac to 1.0345911103112715
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.2273_efac to 0.8427914809395443
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.350_efac to 0.898914858648177
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.P200.1380_log10_tnequad to -6.649000741215544
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.P217.1380_log10_tnequad to -6.6593602574637805
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.S110.2487_log10_tnequad to -7.9772772266290275
# INFO: enterprise.signals.signal_base: Setting J1713+0747_EFF.S60.4857_log10_tnequad to -8.312222023615337
# INFO: enterprise.signals.signal_base: Setting J1713+0747_JBO.MK2.1520_log10_tnequad to -8.095181552632685
# INFO: enterprise.signals.signal_base: Setting J1713+0747_JBO.ROACH.1520_log10_tnequad to -6.615228034705099
# INFO: enterprise.signals.signal_base: Setting J1713+0747_LEAP.1396_log10_tnequad to -6.7185150489060375
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.1484_log10_tnequad to -7.124620438769816
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.1854_log10_tnequad to -8.520459384443132
# INFO: enterprise.signals.signal_base: Setting J1713+0747_NRT.NUPPI.2539_log10_tnequad to -6.868562726735876
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.1380_log10_tnequad to -6.9716719287703555
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.2273_log10_tnequad to -6.676656824013697
# INFO: enterprise.signals.signal_base: Setting J1713+0747_WSRT.P2.350_log10_tnequad to -8.972410387384546
# INFO: enterprise.signals.signal_base: Setting J1730-2304_JBO.ROACH.1520_efac to 1.0966895598937743
# INFO: enterprise.signals.signal_base: Setting J1730-2304_NRT.NUPPI.1484_efac to 0.8936515336010582
# INFO: enterprise.signals.signal_base: Setting J1730-2304_NRT.NUPPI.2539_efac to 0.82955546014866
# INFO: enterprise.signals.signal_base: Setting J1730-2304_JBO.ROACH.1520_log10_tnequad to -8.76732339089998
# INFO: enterprise.signals.signal_base: Setting J1730-2304_NRT.NUPPI.1484_log10_tnequad to -7.092912342511541
# INFO: enterprise.signals.signal_base: Setting J1730-2304_NRT.NUPPI.2539_log10_tnequad to -8.070483707308561
# INFO: enterprise.signals.signal_base: Setting J1738+0333_EFF.P200.1380_efac to 1.2329115324118975
# INFO: enterprise.signals.signal_base: Setting J1738+0333_EFF.P217.1380_efac to 0.8867280280191301
# INFO: enterprise.signals.signal_base: Setting J1738+0333_JBO.ROACH.1520_efac to 0.7472756385097318
# INFO: enterprise.signals.signal_base: Setting J1738+0333_NRT.NUPPI.1484_efac to 0.8613738492525165
# INFO: enterprise.signals.signal_base: Setting J1738+0333_WSRT.P2.1380_efac to 1.1112003518112685
# INFO: enterprise.signals.signal_base: Setting J1738+0333_EFF.P200.1380_log10_tnequad to -6.79109245509378
# INFO: enterprise.signals.signal_base: Setting J1738+0333_EFF.P217.1380_log10_tnequad to -7.93640722539657
# INFO: enterprise.signals.signal_base: Setting J1738+0333_JBO.ROACH.1520_log10_tnequad to -5.43250967829
# INFO: enterprise.signals.signal_base: Setting J1738+0333_NRT.NUPPI.1484_log10_tnequad to -7.826039383135421
# INFO: enterprise.signals.signal_base: Setting J1738+0333_WSRT.P2.1380_log10_tnequad to -8.662202710812908
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.P200.1380_efac to 1.5289889739981626
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.P217.1380_efac to 1.2771057723574064
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.S110.2487_efac to 1.244705701316738
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.S60.4857_efac to 1.0561167945451462
# INFO: enterprise.signals.signal_base: Setting J1744-1134_JBO.ROACH.1520_efac to 1.1363656211662838
# INFO: enterprise.signals.signal_base: Setting J1744-1134_LEAP.1396_efac to 1.3136587135168925
# INFO: enterprise.signals.signal_base: Setting J1744-1134_NRT.NUPPI.1484_efac to 0.8171455527990248
# INFO: enterprise.signals.signal_base: Setting J1744-1134_NRT.NUPPI.2539_efac to 0.6214279693404747
# INFO: enterprise.signals.signal_base: Setting J1744-1134_WSRT.P2.1380_efac to 1.2098338519224716
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.P200.1380_log10_tnequad to -8.076864368319155
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.P217.1380_log10_tnequad to -7.778377010704876
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.S110.2487_log10_tnequad to -6.53903945008975
# INFO: enterprise.signals.signal_base: Setting J1744-1134_EFF.S60.4857_log10_tnequad to -7.257195389387301
# INFO: enterprise.signals.signal_base: Setting J1744-1134_JBO.ROACH.1520_log10_tnequad to -6.3815473236602775
# INFO: enterprise.signals.signal_base: Setting J1744-1134_LEAP.1396_log10_tnequad to -6.478777690017408
# INFO: enterprise.signals.signal_base: Setting J1744-1134_NRT.NUPPI.1484_log10_tnequad to -6.727670528542976
# INFO: enterprise.signals.signal_base: Setting J1744-1134_NRT.NUPPI.2539_log10_tnequad to -6.520348996009733
# INFO: enterprise.signals.signal_base: Setting J1744-1134_WSRT.P2.1380_log10_tnequad to -6.695781710027594
# INFO: enterprise.signals.signal_base: Setting J1751-2857_JBO.ROACH.1520_efac to 0.7549920950094138
# INFO: enterprise.signals.signal_base: Setting J1751-2857_NRT.NUPPI.1484_efac to 0.7531123951282895
# INFO: enterprise.signals.signal_base: Setting J1751-2857_JBO.ROACH.1520_log10_tnequad to -8.984319052277996
# INFO: enterprise.signals.signal_base: Setting J1751-2857_NRT.NUPPI.1484_log10_tnequad to -8.842148621404872
# INFO: enterprise.signals.signal_base: Setting J1801-1417_JBO.ROACH.1520_efac to 0.9864350427630586
# INFO: enterprise.signals.signal_base: Setting J1801-1417_NRT.NUPPI.1484_efac to 0.7483157602884402
# INFO: enterprise.signals.signal_base: Setting J1801-1417_JBO.ROACH.1520_log10_tnequad to -6.261181331261443
# INFO: enterprise.signals.signal_base: Setting J1801-1417_NRT.NUPPI.1484_log10_tnequad to -6.117048727714347
# INFO: enterprise.signals.signal_base: Setting J1804-2717_JBO.ROACH.1520_efac to 1.0057404787686226
# INFO: enterprise.signals.signal_base: Setting J1804-2717_NRT.NUPPI.1484_efac to 0.8049270400445149
# INFO: enterprise.signals.signal_base: Setting J1804-2717_JBO.ROACH.1520_log10_tnequad to -8.517548525232066
# INFO: enterprise.signals.signal_base: Setting J1804-2717_NRT.NUPPI.1484_log10_tnequad to -7.738473879868597
# INFO: enterprise.signals.signal_base: Setting J1843-1113_EFF.P217.1380_efac to 1.1814583391980884
# INFO: enterprise.signals.signal_base: Setting J1843-1113_EFF.S110.2487_efac to 0.8510196074666396
# INFO: enterprise.signals.signal_base: Setting J1843-1113_JBO.ROACH.1520_efac to 0.5085959354688436
# INFO: enterprise.signals.signal_base: Setting J1843-1113_NRT.NUPPI.1484_efac to 0.7483857925666096
# INFO: enterprise.signals.signal_base: Setting J1843-1113_WSRT.P2.1380_efac to 1.0406588880071412
# INFO: enterprise.signals.signal_base: Setting J1843-1113_EFF.P217.1380_log10_tnequad to -7.348379374130354
# INFO: enterprise.signals.signal_base: Setting J1843-1113_EFF.S110.2487_log10_tnequad to -7.178804349666641
# INFO: enterprise.signals.signal_base: Setting J1843-1113_JBO.ROACH.1520_log10_tnequad to -5.297139966908785
# INFO: enterprise.signals.signal_base: Setting J1843-1113_NRT.NUPPI.1484_log10_tnequad to -8.20133231501511
# INFO: enterprise.signals.signal_base: Setting J1843-1113_WSRT.P2.1380_log10_tnequad to -6.567219495870018
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.P200.1380_efac to 0.8903961781606221
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.P217.1380_efac to 0.5727944719143326
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.S110.2487_efac to 0.8872282802497014
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.S60.4857_efac to 0.7349637319778864
# INFO: enterprise.signals.signal_base: Setting J1857+0943_JBO.ROACH.1520_efac to 1.2238336779590848
# INFO: enterprise.signals.signal_base: Setting J1857+0943_LEAP.1396_efac to 1.5409148049950512
# INFO: enterprise.signals.signal_base: Setting J1857+0943_NRT.NUPPI.1484_efac to 0.9416000131448992
# INFO: enterprise.signals.signal_base: Setting J1857+0943_NRT.NUPPI.2539_efac to 0.9509516872455311
# INFO: enterprise.signals.signal_base: Setting J1857+0943_WSRT.P2.1380_efac to 0.9497468011319526
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.P200.1380_log10_tnequad to -8.08507027056367
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.P217.1380_log10_tnequad to -5.651476519327127
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.S110.2487_log10_tnequad to -5.5312698143074845
# INFO: enterprise.signals.signal_base: Setting J1857+0943_EFF.S60.4857_log10_tnequad to -8.426628290626866
# INFO: enterprise.signals.signal_base: Setting J1857+0943_JBO.ROACH.1520_log10_tnequad to -6.135956765069297
# INFO: enterprise.signals.signal_base: Setting J1857+0943_LEAP.1396_log10_tnequad to -6.855223837221721
# INFO: enterprise.signals.signal_base: Setting J1857+0943_NRT.NUPPI.1484_log10_tnequad to -8.900236976699127
# INFO: enterprise.signals.signal_base: Setting J1857+0943_NRT.NUPPI.2539_log10_tnequad to -8.33485330361282
# INFO: enterprise.signals.signal_base: Setting J1857+0943_WSRT.P2.1380_log10_tnequad to -8.621053689913959
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.1484_efac to 0.8540704265946855
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.1854_efac to 0.7676705441810963
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.2154_efac to 1.03247195323751
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.2539_efac to 0.7010197803207379
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.1484_log10_tnequad to -7.415073878834863
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.1854_log10_tnequad to -7.120859176440731
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.2154_log10_tnequad to -7.230582195698377
# INFO: enterprise.signals.signal_base: Setting J1909-3744_NRT.NUPPI.2539_log10_tnequad to -6.971700069604973
# INFO: enterprise.signals.signal_base: Setting J1910+1256_JBO.ROACH.1520_efac to 1.0605708987634797
# INFO: enterprise.signals.signal_base: Setting J1910+1256_NRT.NUPPI.1484_efac to 0.8345119172671124
# INFO: enterprise.signals.signal_base: Setting J1910+1256_JBO.ROACH.1520_log10_tnequad to -8.60288324441584
# INFO: enterprise.signals.signal_base: Setting J1910+1256_NRT.NUPPI.1484_log10_tnequad to -6.560712227869687
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.P200.1380_efac to 0.8761134222727486
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.P217.1380_efac to 1.4282541670316486
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.S110.2487_efac to 1.6558234534679714
# INFO: enterprise.signals.signal_base: Setting J1911+1347_JBO.ROACH.1520_efac to 0.8120162030722926
# INFO: enterprise.signals.signal_base: Setting J1911+1347_NRT.NUPPI.1484_efac to 0.8145191417597308
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.P200.1380_log10_tnequad to -6.325898247530114
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.P217.1380_log10_tnequad to -8.972867072178717
# INFO: enterprise.signals.signal_base: Setting J1911+1347_EFF.S110.2487_log10_tnequad to -5.8910997224670405
# INFO: enterprise.signals.signal_base: Setting J1911+1347_JBO.ROACH.1520_log10_tnequad to -5.504056196974953
# INFO: enterprise.signals.signal_base: Setting J1911+1347_NRT.NUPPI.1484_log10_tnequad to -8.815757478736355
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.P200.1380_efac to 0.911571024305496
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.P217.1380_efac to 1.1332353140352633
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.S110.2487_efac to 0.5276154326065083
# INFO: enterprise.signals.signal_base: Setting J1918-0642_JBO.ROACH.1520_efac to 0.9655238565741925
# INFO: enterprise.signals.signal_base: Setting J1918-0642_LEAP.1396_efac to 0.6781781812273364
# INFO: enterprise.signals.signal_base: Setting J1918-0642_NRT.NUPPI.1484_efac to 0.831041493837829
# INFO: enterprise.signals.signal_base: Setting J1918-0642_WSRT.P2.1380_efac to 0.9493532309055206
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.P200.1380_log10_tnequad to -6.339692244024356
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.P217.1380_log10_tnequad to -7.9507971426473105
# INFO: enterprise.signals.signal_base: Setting J1918-0642_EFF.S110.2487_log10_tnequad to -5.583677452793728
# INFO: enterprise.signals.signal_base: Setting J1918-0642_JBO.ROACH.1520_log10_tnequad to -6.332914721246314
# INFO: enterprise.signals.signal_base: Setting J1918-0642_LEAP.1396_log10_tnequad to -5.796154707117647
# INFO: enterprise.signals.signal_base: Setting J1918-0642_NRT.NUPPI.1484_log10_tnequad to -6.636962947462052
# INFO: enterprise.signals.signal_base: Setting J1918-0642_WSRT.P2.1380_log10_tnequad to -7.45893781848895
# INFO: enterprise.signals.signal_base: Setting J2124-3358_JBO.ROACH.1520_efac to 1.3225391415374796
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.1484_efac to 0.8358609453728573
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.1854_efac to 0.808915114390453
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.2154_efac to 1.128419743531647
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.2539_efac to 0.6632723665048084
# INFO: enterprise.signals.signal_base: Setting J2124-3358_JBO.ROACH.1520_log10_tnequad to -8.02686408638112
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.1484_log10_tnequad to -8.868578577184497
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.1854_log10_tnequad to -5.254878544747536
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.2154_log10_tnequad to -7.4274298640233125
# INFO: enterprise.signals.signal_base: Setting J2124-3358_NRT.NUPPI.2539_log10_tnequad to -5.366358828495574
# INFO: enterprise.signals.signal_base: Setting J2322+2057_EFF.P217.1380_efac to 1.2087043553497132
# INFO: enterprise.signals.signal_base: Setting J2322+2057_JBO.ROACH.1520_efac to 0.9610659725859465
# INFO: enterprise.signals.signal_base: Setting J2322+2057_NRT.NUPPI.1484_efac to 0.8809550106099319
# INFO: enterprise.signals.signal_base: Setting J2322+2057_EFF.P217.1380_log10_tnequad to -6.508521806272974
# INFO: enterprise.signals.signal_base: Setting J2322+2057_JBO.ROACH.1520_log10_tnequad to -6.054868484868762
# INFO: enterprise.signals.signal_base: Setting J2322+2057_NRT.NUPPI.1484_log10_tnequad to -8.583883932763115

# %% [markdown]
# In this case, we don't need samples of the white noise and deterministic signal parameters because tehy are fixed in the pta objects. $\sigma_0$ and $\hat{a}_0$ can be computed analytically.

# %%
#### ANALYTICAL \Sigma_0 and \hat{a}_0

TNTs = pta_0.get_TNT([])
TNrs = pta_0.get_TNr([])
phiinvs_0 = pta_0.get_phiinv([],logdet=True)

Sigma_0_inv = []
a_hat = []

for TNr, TNT, pl in zip(TNrs, TNTs, phiinvs_0):
    phiinv, logdet_phi = pl
    Sigma_0_inv_step = TNT + (np.diag(phiinv) if phiinv.ndim == 1 else phiinv)
    Li, lower = sl.cho_factor(Sigma_0_inv_step, lower=True)
    a_hat_step = sl.cho_solve((Li, True), TNr)
    Sigma_0_inv.append(Sigma_0_inv_step)
    a_hat.append(a_hat_step)

logdet_sigma_0 = 0
for S0 in Sigma_0_inv:
    Li, lower = sl.cho_factor(S0, lower=True)
    logdet_sigma_0 += np.sum(2 * np.log(np.diag(Li)))

# sigma 0 * a hat
Si0_a_hat = []
for p in range(Npsrs):
    Si0_a_hat.append(np.dot(Sigma_0_inv[p][:][:], a_hat[p][:]))

# %%
if pta_fl._commonsignals:

    # phiinv_0
    phiinv_0 = []
    for i in range(Npsrs):
        phiinv_0 = np.concatenate((phiinv_0, phiinvs_0[i][0]))
    phiinv_0 = np.diag(phiinv_0)
    phiinv_00 = phiinv_0

    # Sigma_0_inv
    Sigma_0_inv = sl.block_diag(*Sigma_0_inv)

    # Sigma_0 * a hat
    Si0_a_hat_all = Si0_a_hat 
    Si0_a_hat = []
    for i in range(Npsrs):
        Si0_a_hat  = np.concatenate((Si0_a_hat , Si0_a_hat_all[i]))

# %%
# COMPARING THE LIKELIHOOD VALUE OBTAINED WITH THE TIME- AND THE FOURIER-DOMAIN LIKELIHOOD

xs = {par.name: par.sample() for par in pta_fl.params}
lnL_f = log_likelihood_Fourier(xs)
lnL_t = pta_fl.get_lnlikelihood(xs)
print('Fourier-domain ln_likelihood: ',lnL_f,'\n')
print('Time-domain ln_likelihood: ', lnL_t,'\n')
print('difference: ',lnL_f-lnL_t)
# Out:
# Fourier-domain ln_likelihood:  521232.07137636153
#
# Time-domain ln_likelihood:  521232.071376364
#
# difference:  -2.444721758365631e-09

# %%
:)
